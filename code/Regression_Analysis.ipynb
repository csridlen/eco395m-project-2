# %% [markdown]
# # Title

# %% [markdown]
# * bullet point
# * bullet point

# %%
# Libraries set-up

# %load_ext lab_black
import numpy as np
import pandas as pd
from sklearn import linear_model
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm
from scipy import stats
from sklearn.metrics import mean_squared_error
from readtable import getairbnbdata

# %% [markdown]
# ----------------
# ## Data Loading and Manipulation

# %%
# Import data and keep interesting subset of columns for all analyses, drop empty rows,
# remove data with wrong boroughs, rename borough and neighborhood columns
data = (
    pd.read_csv("../data/cleaned_data_updated.csv",)[
        [
            "price",
            "new_neighbourhood",
            "neighbourhood",
            "number_of_reviews",
            "review_scores_rating",
            "review_scores_accuracy",
            "review_scores_cleanliness",
            "review_scores_checkin",
            "review_scores_communication",
            "review_scores_location",
            "review_scores_value",
            "station_dist",
            "station_dist2",
            "park_dist",
            "park_dist2",
            "beds",
            "accommodates",
        ]
    ]
    .dropna()
    .reset_index()
    .rename(columns={"neighbourhood": "borough", "new_neighbourhood": "neighbourhood"})
)

# %%
# tidying the borough coloumn
data["borough"] = data["borough"].str.replace(", New York, United States", "")
data = data[
    (data["borough"] == "Brooklyn")
    | (data["borough"] == "Manhattan")
    | (data["borough"] == "Queens")
    | (data["borough"] == "Bronx")
    | (data["borough"] == "Staten Island")
].reset_index()

# %% [markdown]
# ----------------
# ## Regression Analysis

# %%
# Set up price as Y (dependent variable) for all regressions

Y = data["price"]

# %%
# Define function that outputs regressor matrix depending on what we want to do using subset of data taking as an input a list of regressors

regressors = []


def Xcreator(regressors):
    datax = data[regressors]
    if "borough" in datax.columns:
        datax = pd.get_dummies(datax, columns=["borough"])
        datax = datax.drop(columns="borough_Bronx", axis=1)
    if "neighbourhood" in datax.columns:
        datax = pd.get_dummies(datax, columns=["neighbourhood"])
        datax = datax.drop(columns="neighbourhood_Allerton", axis=1)
    Xt = datax
    X = sm.add_constant(Xt)
    return X

# %%
# Define code that outputs regression


def regress(y, x):
    est = sm.OLS(y, x)
    estr = est.fit()
    print(estr.summary())

# %% [markdown]
# First, we run the regression on boroughs only.

# %%
X1 = Xcreator(["borough"])
regress(Y, X1)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.029
# Model:                            OLS   Adj. R-squared:                  0.029
# Method:                 Least Squares   F-statistic:                     97.55
# Date:                Fri, 13 May 2022   Prob (F-statistic):           6.15e-82
# Time:                        00:21:59   Log-Likelihood:                -82737.
# No. Observations:               13058   AIC:                         1.655e+05
# Df Residuals:                   13053   BIC:                         1.655e+05
# Df Model:                           4
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                    98.5254      5.816     16.941      0.000      87.126     109.925
# borough_Brooklyn         58.7282      5.997      9.793      0.000      46.974      70.483
# borough_Manhattan       446.4746     32.727     13.642      0.000     382.325     510.625
# borough_Queens           26.0093      6.275      4.145      0.000      13.710      38.309
# borough_Staten Island    10.7227      9.059      1.184      0.237      -7.034      28.480
# ==============================================================================
# Omnibus:                    13942.363   Durbin-Watson:                   1.952
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1437637.123
# Skew:                           5.298   Prob(JB):                         0.00
# Kurtosis:                      53.300   Cond. No.                         34.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /Users/steven_unique/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %% [markdown]
# Next, we run the regression on neighbourhoods.

# %%
X2 = Xcreator(["neighbourhood"])
regress(Y, X2)
# Out:
# /Users/steven_unique/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.136
# Model:                            OLS   Adj. R-squared:                  0.124
# Method:                 Least Squares   F-statistic:                     11.46
# Date:                Fri, 13 May 2022   Prob (F-statistic):          3.00e-285
# Time:                        00:21:59   Log-Likelihood:                -81974.
# No. Observations:               13058   AIC:                         1.643e+05
# Df Residuals:                   12880   BIC:                         1.656e+05
# Df Model:                         177
# Covariance Type:            nonrobust
# =======================================================================================================================================
#                                                                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------------------------------
# const                                                                 130.8571     49.042      2.668      0.008      34.728     226.986
# neighbourhood_Annadale-Huguenot-Prince's Bay-Woodrow                   25.3929     81.327      0.312      0.755    -134.019     184.805
# neighbourhood_Arden Heights-Rossville                                 -52.8571     75.975     -0.696      0.487    -201.780      96.065
# neighbourhood_Astoria (Central)                                       -15.7278     49.888     -0.315      0.753    -113.516      82.061
# neighbourhood_Astoria (East)-Woodside (North)                         -31.6357     50.253     -0.630      0.529    -130.139      66.867
# neighbourhood_Astoria (North)-Ditmars-Steinway                         -9.5437     50.306     -0.190      0.850    -108.152      89.064
# neighbourhood_Astoria Park                                             -5.8571    104.033     -0.056      0.955    -209.778     198.063
# neighbourhood_Auburndale                                              -17.9341     55.250     -0.325      0.745    -126.233      90.365
# neighbourhood_Baisley Park                                            -34.2381     50.650     -0.676      0.499    -133.520      65.044
# neighbourhood_Bath Beach                                                6.4643     54.830      0.118      0.906    -101.011     113.940
# neighbourhood_Bay Ridge                                               -15.0794     50.487     -0.299      0.765    -114.042      83.884
# neighbourhood_Bay Terrace-Clearview                                   489.5429     75.975      6.443      0.000     340.620     638.465
# neighbourhood_Bayside                                                  47.2792     56.306      0.840      0.401     -63.089     157.647
# neighbourhood_Bedford Park                                            -40.8571     62.734     -0.651      0.515    -163.826      82.112
# neighbourhood_Bedford-Stuyvesant (East)                                 5.2805     49.220      0.107      0.915     -91.199     101.760
# neighbourhood_Bedford-Stuyvesant (West)                                17.1731     49.277      0.349      0.727     -79.417     113.763
# neighbourhood_Bellerose                                               -36.1071     81.327     -0.444      0.657    -195.519     123.305
# neighbourhood_Belmont                                                 -46.5571     63.943     -0.728      0.467    -171.894      78.780
# neighbourhood_Bensonhurst                                             -33.5238     53.261     -0.629      0.529    -137.924      70.876
# neighbourhood_Borough Park                                            -99.8571     89.538     -1.115      0.265    -275.364      75.650
# neighbourhood_Breezy Point-Belle Harbor-Rockaway Park-Broad Channel    55.0317     65.389      0.842      0.400     -73.140     183.204
# neighbourhood_Brighton Beach                                            9.6095     54.464      0.176      0.860     -97.147     116.366
# neighbourhood_Brooklyn Heights                                        258.6322     52.567      4.920      0.000     155.593     361.671
# neighbourhood_Brooklyn Navy Yard                                       54.1429    104.033      0.520      0.603    -149.778     258.063
# neighbourhood_Brownsville                                             -64.6777     53.261     -1.214      0.225    -169.078      39.723
# neighbourhood_Bushwick (East)                                          -5.0576     49.399     -0.102      0.918    -101.886      91.771
# neighbourhood_Bushwick (West)                                         -16.5630     49.499     -0.335      0.738    -113.588      80.461
# neighbourhood_Calvary & Mount Zion Cemeteries                         142.4762     89.538      1.591      0.112     -33.031     317.983
# neighbourhood_Cambria Heights                                         -14.3571     61.709     -0.233      0.816    -135.317     106.603
# neighbourhood_Canarsie                                                -10.6502     50.018     -0.213      0.831    -108.694      87.393
# neighbourhood_Canarsie Park & Pier                                    134.6429     67.153      2.005      0.045       3.013     266.273
# neighbourhood_Carroll Gardens-Cobble Hill-Gowanus-Red Hook             95.2006     49.490      1.924      0.054      -1.808     192.209
# neighbourhood_Castle Hill-Unionport                                   -31.8571    138.711     -0.230      0.818    -303.751     240.037
# neighbourhood_Clinton Hill                                             69.7600     49.809      1.401      0.161     -27.873     167.393
# neighbourhood_Co-op City                                              -63.3571     81.327     -0.779      0.436    -222.769      96.055
# neighbourhood_College Point                                           -22.2571     56.981     -0.391      0.696    -133.949      89.435
# neighbourhood_Concourse-Concourse Village                             -43.5863     52.496     -0.830      0.406    -146.486      59.314
# neighbourhood_Coney Island-Sea Gate                                   120.6629     55.484      2.175      0.030      11.905     229.420
# neighbourhood_Corona                                                  -55.9586     51.469     -1.087      0.277    -156.846      44.929
# neighbourhood_Crotona Park East                                       -62.5844     62.734     -0.998      0.318    -185.553      60.384
# neighbourhood_Crown Heights (North)                                     7.6932     49.373      0.156      0.876     -89.086     104.472
# neighbourhood_Crown Heights (South)                                    11.2035     50.746      0.221      0.825     -88.266     110.673
# neighbourhood_Cypress Hills                                           -11.4512     50.713     -0.226      0.821    -110.856      87.953
# neighbourhood_Douglaston-Little Neck                                  -16.0000     69.355     -0.231      0.818    -151.947     119.947
# neighbourhood_Downtown Brooklyn-DUMBO-Boerum Hill                     125.1672     50.418      2.483      0.013      26.341     223.994
# neighbourhood_Dyker Heights                                           -28.1905     72.187     -0.391      0.696    -169.689     113.308
# neighbourhood_East Elmhurst                                           -24.6264     50.228     -0.490      0.624    -123.080      73.827
# neighbourhood_East Flatbush-Erasmus                                   -14.6009     50.103     -0.291      0.771    -112.810      83.608
# neighbourhood_East Flatbush-Farragut                                  -31.2071     51.142     -0.610      0.542    -131.454      69.039
# neighbourhood_East Flatbush-Remsen Village                             -2.6250     52.017     -0.050      0.960    -104.585      99.335
# neighbourhood_East Flatbush-Rugby                                     -36.2571     51.142     -0.709      0.478    -136.504      63.989
# neighbourhood_East Flushing                                            13.1656     52.799      0.249      0.803     -90.328     116.659
# neighbourhood_East Midtown-Turtle Bay                                 554.8095     65.389      8.485      0.000     426.637     682.982
# neighbourhood_East New York (North)                                   -27.1850     50.429     -0.539      0.590    -126.033      71.663
# neighbourhood_East New York-City Line                                 -21.1841     52.238     -0.406      0.685    -123.579      81.211
# neighbourhood_East New York-New Lots                                   -6.8313     50.137     -0.136      0.892    -105.107      91.444
# neighbourhood_East Williamsburg                                        41.4578     49.418      0.839      0.402     -55.409     138.325
# neighbourhood_Eastchester-Edenwald-Baychester                          -6.4127     53.598     -0.120      0.905    -111.473      98.647
# neighbourhood_Elmhurst                                                -36.2333     50.592     -0.716      0.474    -135.401      62.934
# neighbourhood_Far Rockaway-Bayswater                                   -9.1738     51.824     -0.177      0.859    -110.756      92.408
# neighbourhood_Financial District-Battery Park City                    569.1429     89.538      6.356      0.000     393.636     744.650
# neighbourhood_Flatbush                                                 -7.7732     50.335     -0.154      0.877    -106.437      90.891
# neighbourhood_Flatbush (West)-Ditmas Park-Parkville                    34.2737     50.620      0.677      0.498     -64.950     133.497
# neighbourhood_Flatlands                                                79.8408     50.798      1.572      0.116     -19.731     179.413
# neighbourhood_Flushing-Willets Point                                  -16.2071     51.142     -0.317      0.751    -116.454      84.039
# neighbourhood_Fordham Heights                                         -77.4821     67.153     -1.154      0.249    -209.112      54.148
# neighbourhood_Forest Hills                                             41.4993     50.713      0.818      0.413     -57.905     140.904
# neighbourhood_Fort Greene                                              63.6765     49.923      1.275      0.202     -34.180     161.533
# neighbourhood_Fresh Meadows-Utopia                                      8.4762     55.737      0.152      0.879    -100.776     117.728
# neighbourhood_Glendale                                                -39.3810     56.629     -0.695      0.487    -150.381      71.619
# neighbourhood_Grasmere-Arrochar-South Beach-Dongan Hills              -59.6538     51.869     -1.150      0.250    -161.326      42.018
# neighbourhood_Gravesend (East)-Homecrest                              -27.4669     53.063     -0.518      0.605    -131.479      76.545
# neighbourhood_Gravesend (South)                                       -35.8571     65.389     -0.548      0.583    -164.029      92.315
# neighbourhood_Gravesend (West)                                        -11.6971     55.484     -0.211      0.833    -120.455      97.060
# neighbourhood_Great Kills-Eltingville                                  -0.2857     60.064     -0.005      0.996    -118.019     117.448
# neighbourhood_Greenpoint                                               87.6374     49.662      1.765      0.078      -9.707     184.982
# neighbourhood_Hamilton Heights-Sugar Hill                             129.1429     89.538      1.442      0.149     -46.364     304.650
# neighbourhood_Highbridge                                              -38.4571     63.943     -0.601      0.548    -163.794      86.880
# neighbourhood_Hollis                                                  -46.4748     53.854     -0.863      0.388    -152.037      59.087
# neighbourhood_Holy Cross Cemetery                                     -39.3571     72.187     -0.545      0.586    -180.855     102.141
# neighbourhood_Howard Beach-Lindenwood                                  -3.7771     55.484     -0.068      0.946    -112.535     104.980
# neighbourhood_Hunts Point                                             -82.6571     75.975     -1.088      0.277    -231.580      66.265
# neighbourhood_Jackson Heights                                         -22.7476     50.204     -0.453      0.650    -121.154      75.659
# neighbourhood_Jacob Riis Park-Fort Tilden-Breezy Point Tip             33.1429    104.033      0.319      0.750    -170.778     237.063
# neighbourhood_Jamaica                                                  90.7029     55.484      1.635      0.102     -18.055     199.460
# neighbourhood_Jamaica Estates-Holliswood                               15.7679     58.799      0.268      0.789     -99.487     131.023
# neighbourhood_Jamaica Hills-Briarwood                                 -51.8187     55.250     -0.938      0.348    -160.118      56.480
# neighbourhood_Kensington                                              164.7679     52.017      3.168      0.002      62.808     266.728
# neighbourhood_Kew Gardens                                             -48.9371     55.484     -0.882      0.378    -157.695      59.820
# neighbourhood_Kew Gardens Hills                                        15.5776     56.010      0.278      0.781     -94.209     125.365
# neighbourhood_Kingsbridge Heights-Van Cortlandt Village               -14.8571     69.355     -0.214      0.830    -150.804     121.090
# neighbourhood_Kingsbridge-Marble Hill                                  16.2857     69.355      0.235      0.814    -119.661     152.233
# neighbourhood_Laurelton                                               -30.1986     53.063     -0.569      0.569    -134.211      73.813
# neighbourhood_Lincoln Terrace Park                                    -48.9821     67.153     -0.729      0.466    -180.612      82.648
# neighbourhood_Long Island City-Hunters Point                           41.2987     51.222      0.806      0.420     -59.105     141.702
# neighbourhood_Longwood                                                 -6.5238     89.538     -0.073      0.942    -182.031     168.983
# neighbourhood_Madison                                                 -15.9848     52.567     -0.304      0.761    -119.024      87.054
# neighbourhood_Manhattanville-West Harlem                              122.1429     89.538      1.364      0.173     -53.364     297.650
# neighbourhood_Mapleton-Midwood (West)                                 -43.1905     89.538     -0.482      0.630    -218.697     132.316
# neighbourhood_Marine Park-Mill Basin-Bergen Beach                      11.4762     55.033      0.209      0.835     -96.397     119.349
# neighbourhood_Mariner's Harbor-Arlington-Graniteville                 -34.7946     58.799     -0.592      0.554    -150.049      80.460
# neighbourhood_Maspeth                                                   1.7081     56.010      0.030      0.976    -108.079     111.495
# neighbourhood_Melrose                                                 -64.1905     65.389     -0.982      0.326    -192.363      63.982
# neighbourhood_Middle Village                                          -18.7905     59.392     -0.316      0.752    -135.209      97.628
# neighbourhood_Middle Village Cemetery                                 -25.8571    138.711     -0.186      0.852    -297.751     246.037
# neighbourhood_Midwood                                                 -45.9892     52.180     -0.881      0.378    -148.270      56.291
# neighbourhood_Morris Park                                             -71.7857     60.064     -1.195      0.232    -189.519      45.948
# neighbourhood_Morrisania                                              -54.0879     60.829     -0.889      0.374    -173.321      65.146
# neighbourhood_Mott Haven-Port Morris                                    1.5464     51.966      0.030      0.976    -100.314     103.407
# neighbourhood_Mount Eden-Claremont (West)                             -90.8571     89.538     -1.015      0.310    -266.364      84.650
# neighbourhood_Mount Hope                                              -39.7359     53.993     -0.736      0.462    -145.571      66.099
# neighbourhood_Mount Olivet & All Faiths Cemeteries                    -69.3571     81.327     -0.853      0.394    -228.769      90.055
# neighbourhood_Murray Hill-Broadway Flushing                            19.4206     57.796      0.336      0.737     -93.869     132.710
# neighbourhood_New Dorp-Midland Beach                                  -10.2256     53.368     -0.192      0.848    -114.835      94.383
# neighbourhood_New Springville-Willowbrook-Bulls Head-Travis            -4.8571     81.327     -0.060      0.952    -164.269     154.555
# neighbourhood_North Corona                                            -28.4613     52.496     -0.542      0.588    -131.361      74.439
# neighbourhood_Norwood                                                 -81.8571     72.187     -1.134      0.257    -223.355      59.641
# neighbourhood_Oakwood-Richmondtown                                     23.7429     63.943      0.371      0.710    -101.594     149.080
# neighbourhood_Ocean Hill                                               -0.6237     49.792     -0.013      0.990     -98.224      96.976
# neighbourhood_Old Astoria-Hallets Point                               -11.5781     52.883     -0.219      0.827    -115.237      92.081
# neighbourhood_Ozone Park                                              -18.4055     54.297     -0.339      0.735    -124.836      88.025
# neighbourhood_Ozone Park (North)                                      -17.5844     62.734     -0.280      0.779    -140.553     105.384
# neighbourhood_Park Slope                                               60.1829     49.611      1.213      0.225     -37.061     157.427
# neighbourhood_Parkchester                                             -87.1429     69.355     -1.256      0.209    -223.090      48.804
# neighbourhood_Pelham Bay Park                                         285.8095     89.538      3.192      0.001     110.303     461.316
# neighbourhood_Pelham Bay-Country Club-City Island                      -6.3929     54.830     -0.117      0.907    -113.868     101.083
# neighbourhood_Pelham Gardens                                          -35.7056     53.993     -0.661      0.508    -141.540      70.129
# neighbourhood_Pelham Parkway-Van Nest                                 -43.5238     72.187     -0.603      0.547    -185.022      97.974
# neighbourhood_Pomonok-Electchester-Hillcrest                          -58.6264     53.261     -1.101      0.271    -163.027      45.774
# neighbourhood_Port Richmond                                           -73.2571     55.484     -1.320      0.187    -182.015      35.500
# neighbourhood_Prospect Heights                                         72.2786     50.253      1.438      0.150     -26.224     170.782
# neighbourhood_Prospect Lefferts Gardens-Wingate                       -12.9198     49.605     -0.260      0.795    -110.153      84.313
# neighbourhood_Queens Village                                           -6.3477     52.180     -0.122      0.903    -108.628      95.933
# neighbourhood_Queensboro Hill                                         -43.4801     51.779     -0.840      0.401    -144.975      58.015
# neighbourhood_Queensbridge-Ravenswood-Dutch Kills                      45.5546     51.504      0.884      0.376     -55.401     146.510
# neighbourhood_Rego Park                                                 4.5095     54.464      0.083      0.934    -102.247     111.266
# neighbourhood_Richmond Hill                                             4.5132     55.033      0.082      0.935    -103.360     112.386
# neighbourhood_Ridgewood                                               -39.0276     50.007     -0.780      0.435    -137.050      58.994
# neighbourhood_Riverdale-Spuyten Duyvil                                207.3929     81.327      2.550      0.011      47.981     366.805
# neighbourhood_Rockaway Beach-Arverne-Edgemere                         119.6366     50.103      2.388      0.017      21.427     217.846
# neighbourhood_Rockaway Community Park                                  65.4762     89.538      0.731      0.465    -110.031     240.983
# neighbourhood_Rosebank-Shore Acres-Park Hill                          -31.3277     58.270     -0.538      0.591    -145.546      82.891
# neighbourhood_Rosedale                                                -31.0655     52.496     -0.592      0.554    -133.965      71.835
# neighbourhood_Sheepshead Bay-Manhattan Beach-Gerritsen Beach           51.5342     52.641      0.979      0.328     -51.650     154.718
# neighbourhood_Soundview-Bruckner-Bronx River                          -40.8571     63.943     -0.639      0.523    -166.194      84.480
# neighbourhood_Soundview-Clason Point                                  -34.4725     55.250     -0.624      0.533    -142.772      73.827
# neighbourhood_South Jamaica                                            -4.4887     53.368     -0.084      0.933    -109.098     100.120
# neighbourhood_South Ozone Park                                         25.9970     52.496      0.495      0.620     -76.903     128.897
# neighbourhood_South Richmond Hill                                     -40.9238     59.392     -0.689      0.491    -157.342      75.494
# neighbourhood_South Williamsburg                                      193.7857     54.830      3.534      0.000      86.310     301.261
# neighbourhood_Spring Creek-Starrett City                              -66.0238     72.187     -0.915      0.360    -207.522      75.474
# neighbourhood_Springfield Gardens (North)-Rochdale Village             13.0420     50.464      0.258      0.796     -85.874     111.958
# neighbourhood_Springfield Gardens (South)-Brookville                   18.3638     50.999      0.360      0.719     -81.601     118.329
# neighbourhood_St. Albans                                               -7.5020     50.620     -0.148      0.882    -106.726      91.722
# neighbourhood_St. George-New Brighton                                 -29.9700     51.736     -0.579      0.562    -131.381      71.441
# neighbourhood_Sunnyside                                               -31.5153     50.487     -0.624      0.532    -130.478      67.448
# neighbourhood_Sunnyside Yards (South)                                 -53.8571    104.033     -0.518      0.605    -257.778     150.063
# neighbourhood_Sunset Park (Central)                                    -7.3571     53.368     -0.138      0.890    -111.966      97.252
# neighbourhood_Sunset Park (East)-Borough Park (West)                  -75.8571     89.538     -0.847      0.397    -251.364      99.650
# neighbourhood_Sunset Park (West)                                       10.1493     50.137      0.202      0.840     -88.126     108.425
# neighbourhood_Throgs Neck-Schuylerville                               -61.2971     55.484     -1.105      0.269    -170.055      47.460
# neighbourhood_Todt Hill-Emerson Hill-Lighthouse Hill-Manor Heights    -71.8571     89.538     -0.803      0.422    -247.364     103.650
# neighbourhood_Tompkinsville-Stapleton-Clifton-Fox Hills                22.9137     52.496      0.436      0.662     -79.986     125.814
# neighbourhood_Tottenville-Charleston                                  176.3929     81.327      2.169      0.030      16.981     335.805
# neighbourhood_Tremont                                                  -7.6571     63.943     -0.120      0.905    -132.994     117.680
# neighbourhood_University Heights (North)-Fordham                      -71.7857     60.064     -1.195      0.232    -189.519      45.948
# neighbourhood_University Heights (South)-Morris Heights               -57.4571     56.981     -1.008      0.313    -169.149      54.235
# neighbourhood_Wakefield-Woodlawn                                      -37.6971     55.484     -0.679      0.497    -146.455      71.060
# neighbourhood_West New Brighton-Silver Lake-Grymes Hill               -22.2797     51.402     -0.433      0.665    -123.036      78.477
# neighbourhood_Westchester Square                                      -59.7143     69.355     -0.861      0.389    -195.661      76.233
# neighbourhood_Westerleigh-Castleton Corners                            37.8571     69.355      0.546      0.585     -98.090     173.804
# neighbourhood_Whitestone-Beechhurst                                   -42.4286     69.355     -0.612      0.541    -178.376      93.518
# neighbourhood_Williamsbridge-Olinville                                -28.4286     54.830     -0.518      0.604    -135.904      79.047
# neighbourhood_Williamsburg                                             79.1683     49.313      1.605      0.108     -17.493     175.830
# neighbourhood_Windsor Terrace-South Slope                              21.0011     50.306      0.417      0.676     -77.607     119.609
# neighbourhood_Woodhaven                                               -45.7919     52.641     -0.870      0.384    -148.976      57.392
# neighbourhood_Woodside                                                -20.1033     50.345     -0.399      0.690    -118.787      78.580
# neighbourhood_Yankee Stadium-Macombs Dam Park                         -56.5238     89.538     -0.631      0.528    -232.031     118.983
# ==============================================================================
# Omnibus:                    13766.025   Durbin-Watson:                   1.932
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1486968.133
# Skew:                           5.157   Prob(JB):                         0.00
# Kurtosis:                      54.251   Cond. No.                         584.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# Since neighbourhoods are a better performing regressor than boroughs, we choose to have neighbourhoods as a feature in the next regression along with number of reviews, all, review scores, and other controls

# %%
X3 = Xcreator(
    [
        "neighbourhood",
        "number_of_reviews",
        "review_scores_rating",
        "review_scores_accuracy",
        "review_scores_cleanliness",
        "review_scores_checkin",
        "review_scores_communication",
        "review_scores_location",
        "review_scores_value",
        "beds",
        "accommodates",
    ]
)
regress(Y, X3)
# Out:
# /Users/steven_unique/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.470
# Model:                            OLS   Adj. R-squared:                  0.462
# Method:                 Least Squares   F-statistic:                     60.99
# Date:                Fri, 13 May 2022   Prob (F-statistic):               0.00
# Time:                        00:21:59   Log-Likelihood:                -78786.
# No. Observations:               13058   AIC:                         1.579e+05
# Df Residuals:                   12870   BIC:                         1.594e+05
# Df Model:                         187
# Covariance Type:            nonrobust
# =======================================================================================================================================
#                                                                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------------------------------
# const                                                                  23.8420     43.509      0.548      0.584     -61.441     109.125
# number_of_reviews                                                      -0.1875      0.013    -14.986      0.000      -0.212      -0.163
# review_scores_rating                                                   57.5414      6.770      8.499      0.000      44.271      70.812
# review_scores_accuracy                                                 12.3546      6.725      1.837      0.066      -0.828      25.537
# review_scores_cleanliness                                              16.3260      4.291      3.804      0.000       7.914      24.738
# review_scores_checkin                                                 -35.9403      6.070     -5.921      0.000     -47.839     -24.042
# review_scores_communication                                           -14.9246      6.438     -2.318      0.020     -27.545      -2.304
# review_scores_location                                                 14.9194      4.551      3.278      0.001       5.998      23.840
# review_scores_value                                                   -52.9821      5.941     -8.917      0.000     -64.628     -41.336
# beds                                                                   14.8159      0.940     15.761      0.000      12.973      16.658
# accommodates                                                           28.6719      0.618     46.385      0.000      27.460      29.883
# neighbourhood_Annadale-Huguenot-Prince's Bay-Woodrow                   59.4679     63.744      0.933      0.351     -65.479     184.415
# neighbourhood_Arden Heights-Rossville                                 -24.5225     59.554     -0.412      0.681    -141.258      92.213
# neighbourhood_Astoria (Central)                                         6.7617     39.111      0.173      0.863     -69.901      83.424
# neighbourhood_Astoria (East)-Woodside (North)                          12.8259     39.398      0.326      0.745     -64.400      90.052
# neighbourhood_Astoria (North)-Ditmars-Steinway                         21.1317     39.435      0.536      0.592     -56.167      98.431
# neighbourhood_Astoria Park                                             57.5296     81.554      0.705      0.481    -102.327     217.387
# neighbourhood_Auburndale                                              -20.2003     43.361     -0.466      0.641    -105.195      64.794
# neighbourhood_Baisley Park                                             -4.1207     39.697     -0.104      0.917     -81.933      73.691
# neighbourhood_Bath Beach                                               -0.9168     42.977     -0.021      0.983     -85.158      83.324
# neighbourhood_Bay Ridge                                               -22.3347     39.573     -0.564      0.572     -99.903      55.234
# neighbourhood_Bay Terrace-Clearview                                   381.9865     59.575      6.412      0.000     265.211     498.762
# neighbourhood_Bayside                                                  42.5688     44.135      0.965      0.335     -43.942     129.080
# neighbourhood_Bedford Park                                             14.0603     49.187      0.286      0.775     -82.354     110.474
# neighbourhood_Bedford-Stuyvesant (East)                                21.3023     38.579      0.552      0.581     -54.319      96.924
# neighbourhood_Bedford-Stuyvesant (West)                                36.2649     38.622      0.939      0.348     -39.441     111.971
# neighbourhood_Bellerose                                               -34.9635     63.754     -0.548      0.583    -159.930      90.003
# neighbourhood_Belmont                                                 -29.4406     50.141     -0.587      0.557    -127.724      68.843
# neighbourhood_Bensonhurst                                             -36.3666     41.751     -0.871      0.384    -118.204      45.471
# neighbourhood_Borough Park                                            -37.3662     70.179     -0.532      0.594    -174.927     100.194
# neighbourhood_Breezy Point-Belle Harbor-Rockaway Park-Broad Channel   107.5240     51.267      2.097      0.036       7.034     208.014
# neighbourhood_Brighton Beach                                           45.4540     42.700      1.064      0.287     -38.245     129.153
# neighbourhood_Brooklyn Heights                                        220.3166     41.210      5.346      0.000     139.538     301.095
# neighbourhood_Brooklyn Navy Yard                                       99.1186     81.554      1.215      0.224     -60.740     258.977
# neighbourhood_Brownsville                                              -6.7105     41.761     -0.161      0.872     -88.569      75.148
# neighbourhood_Bushwick (East)                                           7.1519     38.721      0.185      0.853     -68.746      83.050
# neighbourhood_Bushwick (West)                                          18.0854     38.805      0.466      0.641     -57.977      94.148
# neighbourhood_Calvary & Mount Zion Cemeteries                         -22.4988     70.253     -0.320      0.749    -160.204     115.207
# neighbourhood_Cambria Heights                                         -11.3315     48.368     -0.234      0.815    -106.140      83.477
# neighbourhood_Canarsie                                                 -7.9338     39.211     -0.202      0.840     -84.794      68.926
# neighbourhood_Canarsie Park & Pier                                     14.5003     52.686      0.275      0.783     -88.772     117.773
# neighbourhood_Carroll Gardens-Cobble Hill-Gowanus-Red Hook             91.7747     38.791      2.366      0.018      15.738     167.812
# neighbourhood_Castle Hill-Unionport                                   -69.7324    108.708     -0.641      0.521    -282.816     143.351
# neighbourhood_Clinton Hill                                             76.7687     39.039      1.966      0.049       0.246     153.292
# neighbourhood_Co-op City                                              -15.9569     63.754     -0.250      0.802    -140.924     109.010
# neighbourhood_College Point                                           -12.6805     44.663     -0.284      0.776    -100.226      74.865
# neighbourhood_Concourse-Concourse Village                             -13.5122     41.156     -0.328      0.743     -94.184      67.159
# neighbourhood_Coney Island-Sea Gate                                    73.8806     43.580      1.695      0.090     -11.543     159.304
# neighbourhood_Corona                                                   -5.0941     40.375     -0.126      0.900     -84.236      74.048
# neighbourhood_Crotona Park East                                        -1.1212     49.179     -0.023      0.982     -97.519      95.276
# neighbourhood_Crown Heights (North)                                    15.5581     38.702      0.402      0.688     -60.304      91.421
# neighbourhood_Crown Heights (South)                                    -6.0533     39.786     -0.152      0.879     -84.039      71.932
# neighbourhood_Cypress Hills                                            -2.4873     39.764     -0.063      0.950     -80.430      75.455
# neighbourhood_Douglaston-Little Neck                                   -9.0671     54.370     -0.167      0.868    -115.640      97.506
# neighbourhood_Downtown Brooklyn-DUMBO-Boerum Hill                     123.8791     39.519      3.135      0.002      46.416     201.342
# neighbourhood_Dyker Heights                                           -54.4944     56.575     -0.963      0.335    -165.389      56.401
# neighbourhood_East Elmhurst                                           -19.5632     39.368     -0.497      0.619     -96.730      57.603
# neighbourhood_East Flatbush-Erasmus                                    -4.8540     39.276     -0.124      0.902     -81.840      72.132
# neighbourhood_East Flatbush-Farragut                                   -6.3903     40.098     -0.159      0.873     -84.988      72.208
# neighbourhood_East Flatbush-Remsen Village                            -11.0513     40.785     -0.271      0.786     -90.996      68.894
# neighbourhood_East Flatbush-Rugby                                     -15.8275     40.112     -0.395      0.693     -94.452      62.797
# neighbourhood_East Flushing                                           -17.6436     41.383     -0.426      0.670     -98.761      63.473
# neighbourhood_East Midtown-Turtle Bay                                 567.0642     52.231     10.857      0.000     464.683     669.445
# neighbourhood_East New York (North)                                   -13.0613     39.542     -0.330      0.741     -90.570      64.448
# neighbourhood_East New York-City Line                                 -27.7965     40.961     -0.679      0.497    -108.087      52.494
# neighbourhood_East New York-New Lots                                   -6.8781     39.319     -0.175      0.861     -83.950      70.193
# neighbourhood_East Williamsburg                                        65.0475     38.739      1.679      0.093     -10.887     140.982
# neighbourhood_Eastchester-Edenwald-Baychester                         -41.9454     42.013     -0.998      0.318    -124.297      40.406
# neighbourhood_Elmhurst                                                -12.2560     39.666     -0.309      0.757     -90.007      65.496
# neighbourhood_Far Rockaway-Bayswater                                    9.0855     40.634      0.224      0.823     -70.564      88.735
# neighbourhood_Financial District-Battery Park City                    324.6399     70.241      4.622      0.000     186.958     462.322
# neighbourhood_Flatbush                                                  2.7619     39.453      0.070      0.944     -74.572      80.096
# neighbourhood_Flatbush (West)-Ditmas Park-Parkville                    13.0157     39.678      0.328      0.743     -64.758      90.790
# neighbourhood_Flatlands                                                47.9810     39.830      1.205      0.228     -30.091     126.053
# neighbourhood_Flushing-Willets Point                                  -16.4698     40.100     -0.411      0.681     -95.072      62.132
# neighbourhood_Fordham Heights                                         -14.2409     52.650     -0.270      0.787    -117.442      88.961
# neighbourhood_Forest Hills                                             50.4611     39.760      1.269      0.204     -27.475     128.397
# neighbourhood_Fort Greene                                              69.3865     39.132      1.773      0.076      -7.317     146.090
# neighbourhood_Fresh Meadows-Utopia                                     38.6697     43.704      0.885      0.376     -46.997     124.337
# neighbourhood_Glendale                                                -23.2756     44.397     -0.524      0.600    -110.300      63.749
# neighbourhood_Grasmere-Arrochar-South Beach-Dongan Hills              -21.1248     40.672     -0.519      0.603    -100.848      58.598
# neighbourhood_Gravesend (East)-Homecrest                               -9.4637     41.588     -0.228      0.820     -90.982      72.054
# neighbourhood_Gravesend (South)                                         1.5784     51.309      0.031      0.975     -98.996     102.152
# neighbourhood_Gravesend (West)                                        -17.6460     43.501     -0.406      0.685    -102.915      67.623
# neighbourhood_Great Kills-Eltingville                                 -27.4042     47.074     -0.582      0.560    -119.676      64.868
# neighbourhood_Greenpoint                                              103.4426     38.933      2.657      0.008      27.128     179.758
# neighbourhood_Hamilton Heights-Sugar Hill                              80.7903     70.198      1.151      0.250     -56.808     218.389
# neighbourhood_Highbridge                                               -1.9146     50.212     -0.038      0.970    -100.338      96.509
# neighbourhood_Hollis                                                    4.1011     42.235      0.097      0.923     -78.686      86.889
# neighbourhood_Holy Cross Cemetery                                     -23.0030     56.588     -0.407      0.684    -133.923      87.917
# neighbourhood_Howard Beach-Lindenwood                                  31.0754     43.488      0.715      0.475     -54.167     116.318
# neighbourhood_Hunts Point                                             -25.1736     59.569     -0.423      0.673    -141.938      91.591
# neighbourhood_Jackson Heights                                           4.2350     39.361      0.108      0.914     -72.919      81.389
# neighbourhood_Jacob Riis Park-Fort Tilden-Breezy Point Tip             63.3277     81.563      0.776      0.438     -96.548     223.204
# neighbourhood_Jamaica                                                 -26.1300     43.512     -0.601      0.548    -111.419      59.159
# neighbourhood_Jamaica Estates-Holliswood                               61.8048     46.094      1.341      0.180     -28.546     152.156
# neighbourhood_Jamaica Hills-Briarwood                                 -28.8244     43.317     -0.665      0.506    -113.733      56.084
# neighbourhood_Kensington                                              112.5017     40.778      2.759      0.006      32.571     192.432
# neighbourhood_Kew Gardens                                              -4.4461     43.513     -0.102      0.919     -89.738      80.846
# neighbourhood_Kew Gardens Hills                                       -13.5284     43.905     -0.308      0.758     -99.589      72.532
# neighbourhood_Kingsbridge Heights-Van Cortlandt Village                -7.9255     54.407     -0.146      0.884    -114.572      98.721
# neighbourhood_Kingsbridge-Marble Hill                                 -39.1902     54.359     -0.721      0.471    -145.743      67.362
# neighbourhood_Laurelton                                               -21.2864     41.606     -0.512      0.609    -102.840      60.267
# neighbourhood_Lincoln Terrace Park                                    -15.0074     52.717     -0.285      0.776    -118.340      88.325
# neighbourhood_Long Island City-Hunters Point                           66.8525     40.163      1.665      0.096     -11.874     145.579
# neighbourhood_Longwood                                                 -3.5992     70.222     -0.051      0.959    -141.245     134.046
# neighbourhood_Madison                                                 -29.8995     41.202     -0.726      0.468    -110.661      50.862
# neighbourhood_Manhattanville-West Harlem                               41.3866     70.183      0.590      0.555     -96.183     178.957
# neighbourhood_Mapleton-Midwood (West)                                  16.9936     70.177      0.242      0.809    -120.563     154.550
# neighbourhood_Marine Park-Mill Basin-Bergen Beach                      43.3530     43.146      1.005      0.315     -41.219     127.925
# neighbourhood_Mariner's Harbor-Arlington-Graniteville                  -2.4466     46.099     -0.053      0.958     -92.808      87.915
# neighbourhood_Maspeth                                                 -47.7254     43.918     -1.087      0.277    -133.811      38.360
# neighbourhood_Melrose                                                  21.7662     51.266      0.425      0.671     -78.723     122.256
# neighbourhood_Middle Village                                           32.3601     46.572      0.695      0.487     -58.928     123.648
# neighbourhood_Middle Village Cemetery                                 -24.1873    108.735     -0.222      0.824    -237.323     188.949
# neighbourhood_Midwood                                                 -25.4952     40.903     -0.623      0.533    -105.671      54.680
# neighbourhood_Morris Park                                             -12.7047     47.109     -0.270      0.787    -105.045      79.635
# neighbourhood_Morrisania                                              -31.1990     47.679     -0.654      0.513    -124.658      62.260
# neighbourhood_Mott Haven-Port Morris                                   21.9393     40.750      0.538      0.590     -57.936     101.815
# neighbourhood_Mount Eden-Claremont (West)                             -24.7833     70.189     -0.353      0.724    -162.364     112.798
# neighbourhood_Mount Hope                                              -21.1120     42.343     -0.499      0.618    -104.111      61.887
# neighbourhood_Mount Olivet & All Faiths Cemeteries                     -6.5889     63.758     -0.103      0.918    -131.564     118.386
# neighbourhood_Murray Hill-Broadway Flushing                            42.4706     45.304      0.937      0.349     -46.332     131.273
# neighbourhood_New Dorp-Midland Beach                                    9.7445     41.840      0.233      0.816     -72.268      91.757
# neighbourhood_New Springville-Willowbrook-Bulls Head-Travis           -43.8623     63.749     -0.688      0.491    -168.820      81.095
# neighbourhood_North Corona                                            -12.4677     41.144     -0.303      0.762     -93.117      68.181
# neighbourhood_Norwood                                                 -12.2262     56.594     -0.216      0.829    -123.160      98.707
# neighbourhood_Oakwood-Richmondtown                                     15.8385     50.136      0.316      0.752     -82.436     114.113
# neighbourhood_Ocean Hill                                                2.8148     39.039      0.072      0.943     -73.708      79.338
# neighbourhood_Old Astoria-Hallets Point                                12.1881     41.454      0.294      0.769     -69.068      93.444
# neighbourhood_Ozone Park                                               11.8003     42.568      0.277      0.782     -71.640      95.240
# neighbourhood_Ozone Park (North)                                      -23.3535     49.190     -0.475      0.635    -119.774      73.067
# neighbourhood_Park Slope                                               65.5811     38.885      1.687      0.092     -10.640     141.802
# neighbourhood_Parkchester                                             -20.4824     54.377     -0.377      0.706    -127.070      86.105
# neighbourhood_Pelham Bay Park                                          63.8860     70.322      0.908      0.364     -73.955     201.727
# neighbourhood_Pelham Bay-Country Club-City Island                      28.0584     42.977      0.653      0.514     -56.183     112.300
# neighbourhood_Pelham Gardens                                           -8.8807     42.317     -0.210      0.834     -91.827      74.066
# neighbourhood_Pelham Parkway-Van Nest                                 -24.1046     56.583     -0.426      0.670    -135.015      86.806
# neighbourhood_Pomonok-Electchester-Hillcrest                            1.2961     41.777      0.031      0.975     -80.594      83.186
# neighbourhood_Port Richmond                                           -26.7201     43.510     -0.614      0.539    -112.005      58.565
# neighbourhood_Prospect Heights                                         87.7025     39.391      2.226      0.026      10.490     164.915
# neighbourhood_Prospect Lefferts Gardens-Wingate                         4.0397     38.882      0.104      0.917     -72.175      80.255
# neighbourhood_Queens Village                                          -17.6246     40.909     -0.431      0.667     -97.813      62.564
# neighbourhood_Queensboro Hill                                           4.9155     40.594      0.121      0.904     -74.654      84.485
# neighbourhood_Queensbridge-Ravenswood-Dutch Kills                      37.6685     40.377      0.933      0.351     -41.477     116.814
# neighbourhood_Rego Park                                               -27.5035     42.696     -0.644      0.519    -111.194      56.187
# neighbourhood_Richmond Hill                                             3.5064     43.152      0.081      0.935     -81.077      88.090
# neighbourhood_Ridgewood                                                -6.5796     39.207     -0.168      0.867     -83.432      70.273
# neighbourhood_Riverdale-Spuyten Duyvil                                121.7249     63.764      1.909      0.056      -3.262     246.712
# neighbourhood_Rockaway Beach-Arverne-Edgemere                          87.8645     39.274      2.237      0.025      10.882     164.847
# neighbourhood_Rockaway Community Park                                 -41.4286     70.204     -0.590      0.555    -179.038      96.181
# neighbourhood_Rosebank-Shore Acres-Park Hill                           16.7572     45.676      0.367      0.714     -72.775     106.290
# neighbourhood_Rosedale                                                -13.3780     41.162     -0.325      0.745     -94.062      67.306
# neighbourhood_Sheepshead Bay-Manhattan Beach-Gerritsen Beach           36.6723     41.273      0.889      0.374     -44.230     117.574
# neighbourhood_Soundview-Bruckner-Bronx River                           -6.1805     50.133     -0.123      0.902    -104.449      92.088
# neighbourhood_Soundview-Clason Point                                  -25.6319     43.310     -0.592      0.554    -110.527      59.263
# neighbourhood_South Jamaica                                           -23.0748     41.839     -0.552      0.581    -105.085      58.935
# neighbourhood_South Ozone Park                                         18.8234     41.153      0.457      0.647     -61.843      99.489
# neighbourhood_South Richmond Hill                                     -21.1943     46.562     -0.455      0.649    -112.462      70.073
# neighbourhood_South Williamsburg                                      178.8344     42.984      4.161      0.000      94.580     263.089
# neighbourhood_Spring Creek-Starrett City                               12.5153     56.814      0.220      0.826     -98.848     123.879
# neighbourhood_Springfield Gardens (North)-Rochdale Village              0.6293     39.556      0.016      0.987     -76.906      78.164
# neighbourhood_Springfield Gardens (South)-Brookville                   -3.0376     39.973     -0.076      0.939     -81.390      75.315
# neighbourhood_St. Albans                                               16.2921     39.685      0.411      0.681     -61.496      94.080
# neighbourhood_St. George-New Brighton                                 -21.1742     40.552     -0.522      0.602    -100.662      58.314
# neighbourhood_Sunnyside                                                15.7998     39.583      0.399      0.690     -61.788      93.388
# neighbourhood_Sunnyside Yards (South)                                 -10.9348     81.546     -0.134      0.893    -170.778     148.908
# neighbourhood_Sunset Park (Central)                                    25.1417     41.842      0.601      0.548     -56.874     107.158
# neighbourhood_Sunset Park (East)-Borough Park (West)                  -23.1402     70.260     -0.329      0.742    -160.860     114.579
# neighbourhood_Sunset Park (West)                                       18.8990     39.304      0.481      0.631     -58.142      95.940
# neighbourhood_Throgs Neck-Schuylerville                                 7.1355     43.499      0.164      0.870     -78.130      92.401
# neighbourhood_Todt Hill-Emerson Hill-Lighthouse Hill-Manor Heights     10.0103     70.194      0.143      0.887    -127.580     147.601
# neighbourhood_Tompkinsville-Stapleton-Clifton-Fox Hills               -34.2019     41.157     -0.831      0.406    -114.876      46.473
# neighbourhood_Tottenville-Charleston                                  -19.0148     63.776     -0.298      0.766    -144.025     105.995
# neighbourhood_Tremont                                                  35.3976     50.155      0.706      0.480     -62.914     133.709
# neighbourhood_University Heights (North)-Fordham                       -9.0654     47.151     -0.192      0.848    -101.489      83.358
# neighbourhood_University Heights (South)-Morris Heights                 8.6765     44.710      0.194      0.846     -78.962      96.315
# neighbourhood_Wakefield-Woodlawn                                      -19.9293     43.498     -0.458      0.647    -105.192      65.333
# neighbourhood_West New Brighton-Silver Lake-Grymes Hill               -32.2856     40.294     -0.801      0.423    -111.267      46.696
# neighbourhood_Westchester Square                                       -2.5157     54.358     -0.046      0.963    -109.066     104.035
# neighbourhood_Westerleigh-Castleton Corners                           -17.9281     54.373     -0.330      0.742    -124.508      88.651
# neighbourhood_Whitestone-Beechhurst                                   -23.7616     54.372     -0.437      0.662    -130.339      82.815
# neighbourhood_Williamsbridge-Olinville                                 -2.8938     42.988     -0.067      0.946     -87.156      81.368
# neighbourhood_Williamsburg                                            108.1402     38.660      2.797      0.005      32.360     183.920
# neighbourhood_Windsor Terrace-South Slope                              28.1174     39.431      0.713      0.476     -49.174     105.409
# neighbourhood_Woodhaven                                               -11.8530     41.262     -0.287      0.774     -92.733      69.027
# neighbourhood_Woodside                                                 -6.6851     39.471     -0.169      0.866     -84.054      70.684
# neighbourhood_Yankee Stadium-Macombs Dam Park                         -46.0800     70.182     -0.657      0.511    -183.648      91.488
# ==============================================================================
# Omnibus:                    15815.204   Durbin-Watson:                   1.986
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          4493964.751
# Skew:                           6.215   Prob(JB):                         0.00
# Kurtosis:                      93.029   Cond. No.                     5.53e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.53e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# Finally, we add to the former regression two regressors: distance from nearest park and nearest subway station.
#
# We first do this using linear distance and second by using taxi distance and choose which is better.

# %%
# Linear Distance

X4 = Xcreator(
    [
        "neighbourhood",
        "number_of_reviews",
        "review_scores_rating",
        "review_scores_accuracy",
        "review_scores_cleanliness",
        "review_scores_checkin",
        "review_scores_communication",
        "review_scores_location",
        "review_scores_value",
        "beds",
        "accommodates",
        "station_dist",
        "park_dist",
    ]
)
regress(Y, X4)
# Out:
# /Users/steven_unique/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.471
# Model:                            OLS   Adj. R-squared:                  0.463
# Method:                 Least Squares   F-statistic:                     60.55
# Date:                Fri, 13 May 2022   Prob (F-statistic):               0.00
# Time:                        00:22:00   Log-Likelihood:                -78775.
# No. Observations:               13058   AIC:                         1.579e+05
# Df Residuals:                   12868   BIC:                         1.594e+05
# Df Model:                         189
# Covariance Type:            nonrobust
# =======================================================================================================================================
#                                                                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------------------------------
# const                                                                  18.6409     43.568      0.428      0.669     -66.759     104.041
# number_of_reviews                                                      -0.1862      0.013    -14.888      0.000      -0.211      -0.162
# review_scores_rating                                                   58.0415      6.767      8.578      0.000      44.778      71.305
# review_scores_accuracy                                                 11.9563      6.721      1.779      0.075      -1.217      25.130
# review_scores_cleanliness                                              15.7862      4.291      3.679      0.000       7.376      24.197
# review_scores_checkin                                                 -36.0885      6.066     -5.949      0.000     -47.979     -24.198
# review_scores_communication                                           -15.7227      6.437     -2.443      0.015     -28.339      -3.106
# review_scores_location                                                 16.4611      4.566      3.605      0.000       7.512      25.410
# review_scores_value                                                   -52.7605      5.937     -8.886      0.000     -64.399     -41.122
# beds                                                                   14.7825      0.940     15.718      0.000      12.939      16.626
# accommodates                                                           28.6804      0.618     46.397      0.000      27.469      29.892
# station_dist                                                           19.7152      4.865      4.052      0.000      10.179      29.252
# park_dist                                                              -8.4841      4.437     -1.912      0.056     -17.182       0.214
# neighbourhood_Annadale-Huguenot-Prince's Bay-Woodrow                 -121.2878     77.374     -1.568      0.117    -272.953      30.377
# neighbourhood_Arden Heights-Rossville                                -210.4560     75.482     -2.788      0.005    -358.412     -62.500
# neighbourhood_Astoria (Central)                                        12.7977     39.118      0.327      0.744     -63.879      89.474
# neighbourhood_Astoria (East)-Woodside (North)                          19.2595     39.511      0.487      0.626     -58.188      96.707
# neighbourhood_Astoria (North)-Ditmars-Steinway                         23.4617     39.423      0.595      0.552     -53.813     100.736
# neighbourhood_Astoria Park                                             49.5231     81.516      0.608      0.544    -110.260     209.306
# neighbourhood_Auburndale                                              -57.7006     44.325     -1.302      0.193    -144.583      29.182
# neighbourhood_Baisley Park                                            -31.3706     40.192     -0.781      0.435    -110.152      47.411
# neighbourhood_Bath Beach                                               -0.2668     42.946     -0.006      0.995     -84.447      83.913
# neighbourhood_Bay Ridge                                               -20.7775     39.550     -0.525      0.599     -98.301      56.746
# neighbourhood_Bay Terrace-Clearview                                   323.1113     61.256      5.275      0.000     203.041     443.181
# neighbourhood_Bayside                                                 -10.1562     46.006     -0.221      0.825    -100.334      80.022
# neighbourhood_Bedford Park                                             15.4338     49.159      0.314      0.754     -80.924     111.792
# neighbourhood_Bedford-Stuyvesant (East)                                25.0673     38.575      0.650      0.516     -50.545     100.679
# neighbourhood_Bedford-Stuyvesant (West)                                38.6454     38.598      1.001      0.317     -37.013     114.303
# neighbourhood_Bellerose                                               -87.3420     65.100     -1.342      0.180    -214.948      40.264
# neighbourhood_Belmont                                                 -31.5180     50.130     -0.629      0.530    -129.780      66.744
# neighbourhood_Bensonhurst                                             -30.1027     41.751     -0.721      0.471    -111.942      51.736
# neighbourhood_Borough Park                                            -31.0444     70.146     -0.443      0.658    -168.541     106.453
# neighbourhood_Breezy Point-Belle Harbor-Rockaway Park-Broad Channel   100.4977     51.255      1.961      0.050       0.030     200.966
# neighbourhood_Brighton Beach                                           46.8880     42.682      1.099      0.272     -36.775     130.551
# neighbourhood_Brooklyn Heights                                        222.0368     41.185      5.391      0.000     141.308     302.766
# neighbourhood_Brooklyn Navy Yard                                       93.2063     81.512      1.143      0.253     -66.570     252.983
# neighbourhood_Brownsville                                              -5.3538     41.734     -0.128      0.898     -87.159      76.451
# neighbourhood_Bushwick (East)                                          13.0175     38.739      0.336      0.737     -62.917      88.952
# neighbourhood_Bushwick (West)                                          21.0788     38.785      0.543      0.587     -54.945      97.102
# neighbourhood_Calvary & Mount Zion Cemeteries                         -23.5556     70.239     -0.335      0.737    -161.234     114.123
# neighbourhood_Cambria Heights                                         -53.2997     49.827     -1.070      0.285    -150.969      44.369
# neighbourhood_Canarsie                                                -14.0056     39.239     -0.357      0.721     -90.920      62.908
# neighbourhood_Canarsie Park & Pier                                     -7.9471     52.881     -0.150      0.881    -111.601      95.707
# neighbourhood_Carroll Gardens-Cobble Hill-Gowanus-Red Hook             92.4253     38.765      2.384      0.017      16.441     168.410
# neighbourhood_Castle Hill-Unionport                                   -66.6866    108.632     -0.614      0.539    -279.621     146.248
# neighbourhood_Clinton Hill                                             80.0276     39.018      2.051      0.040       3.546     156.509
# neighbourhood_Co-op City                                              -26.6434     63.771     -0.418      0.676    -151.644      98.357
# neighbourhood_College Point                                           -43.6923     45.273     -0.965      0.335    -132.435      45.050
# neighbourhood_Concourse-Concourse Village                             -12.4194     41.147     -0.302      0.763     -93.073      68.234
# neighbourhood_Coney Island-Sea Gate                                    65.6872     43.586      1.507      0.132     -19.747     151.122
# neighbourhood_Corona                                                   -3.2361     40.360     -0.080      0.936     -82.349      75.876
# neighbourhood_Crotona Park East                                        -0.3949     49.153     -0.008      0.994     -96.741      95.952
# neighbourhood_Crown Heights (North)                                    16.5244     38.684      0.427      0.669     -59.301      92.350
# neighbourhood_Crown Heights (South)                                    -4.2746     39.772     -0.107      0.914     -82.233      73.684
# neighbourhood_Cypress Hills                                            -0.2689     39.746     -0.007      0.995     -78.177      77.639
# neighbourhood_Douglaston-Little Neck                                  -87.7886     57.838     -1.518      0.129    -201.159      25.582
# neighbourhood_Downtown Brooklyn-DUMBO-Boerum Hill                     127.6897     39.499      3.233      0.001      50.265     205.114
# neighbourhood_Dyker Heights                                           -58.6544     56.544     -1.037      0.300    -169.489      52.180
# neighbourhood_East Elmhurst                                           -28.7770     39.705     -0.725      0.469    -106.604      49.050
# neighbourhood_East Flatbush-Erasmus                                     2.0983     39.300      0.053      0.957     -74.935      79.131
# neighbourhood_East Flatbush-Farragut                                    0.3377     40.371      0.008      0.993     -78.795      79.471
# neighbourhood_East Flatbush-Remsen Village                             -9.8830     40.759     -0.242      0.808     -89.778      70.012
# neighbourhood_East Flatbush-Rugby                                     -20.1733     40.225     -0.502      0.616     -99.021      58.675
# neighbourhood_East Flushing                                           -33.2589     41.541     -0.801      0.423    -114.685      48.168
# neighbourhood_East Midtown-Turtle Bay                                 568.9379     52.197     10.900      0.000     466.624     671.252
# neighbourhood_East New York (North)                                    -6.9165     39.541     -0.175      0.861     -84.422      70.589
# neighbourhood_East New York-City Line                                 -26.1232     40.963     -0.638      0.524    -106.416      54.170
# neighbourhood_East New York-New Lots                                   -4.9730     39.293     -0.127      0.899     -81.993      72.047
# neighbourhood_East Williamsburg                                        68.5749     38.719      1.771      0.077      -7.319     144.469
# neighbourhood_Eastchester-Edenwald-Baychester                         -42.5362     41.988     -1.013      0.311    -124.839      39.766
# neighbourhood_Elmhurst                                                 -8.0792     39.654     -0.204      0.839     -85.806      69.648
# neighbourhood_Far Rockaway-Bayswater                                    9.0548     40.605      0.223      0.824     -70.537      88.646
# neighbourhood_Financial District-Battery Park City                    326.9226     70.202      4.657      0.000     189.316     464.529
# neighbourhood_Flatbush                                                  6.7067     39.434      0.170      0.865     -70.589      84.002
# neighbourhood_Flatbush (West)-Ditmas Park-Parkville                    15.3233     39.656      0.386      0.699     -62.409      93.056
# neighbourhood_Flatlands                                                38.2110     40.152      0.952      0.341     -40.492     116.914
# neighbourhood_Flushing-Willets Point                                  -16.2614     40.079     -0.406      0.685     -94.822      62.299
# neighbourhood_Fordham Heights                                         -11.4014     52.622     -0.217      0.828    -114.548      91.745
# neighbourhood_Forest Hills                                             49.5355     39.744      1.246      0.213     -28.368     127.439
# neighbourhood_Fort Greene                                              68.5099     39.116      1.751      0.080      -8.163     145.183
# neighbourhood_Fresh Meadows-Utopia                                     13.1711     44.160      0.298      0.766     -73.388      99.731
# neighbourhood_Glendale                                                -30.6882     44.413     -0.691      0.490    -117.745      56.369
# neighbourhood_Grasmere-Arrochar-South Beach-Dongan Hills              -70.7455     42.646     -1.659      0.097    -154.338      12.847
# neighbourhood_Gravesend (East)-Homecrest                               -7.1192     41.563     -0.171      0.864     -88.588      74.350
# neighbourhood_Gravesend (South)                                         5.2435     51.278      0.102      0.919     -95.269     105.756
# neighbourhood_Gravesend (West)                                        -13.8182     43.478     -0.318      0.751     -99.041      71.404
# neighbourhood_Great Kills-Eltingville                                -180.0664     60.305     -2.986      0.003    -298.274     -61.859
# neighbourhood_Greenpoint                                              103.8632     38.908      2.669      0.008      27.597     180.130
# neighbourhood_Hamilton Heights-Sugar Hill                              83.1894     70.163      1.186      0.236     -54.340     220.719
# neighbourhood_Highbridge                                               -4.2596     50.192     -0.085      0.932    -102.643      94.124
# neighbourhood_Hollis                                                   -6.5280     42.505     -0.154      0.878     -89.845      76.789
# neighbourhood_Holy Cross Cemetery                                     -17.7319     56.682     -0.313      0.754    -128.838      93.374
# neighbourhood_Howard Beach-Lindenwood                                  32.9563     43.651      0.755      0.450     -52.606     118.518
# neighbourhood_Hunts Point                                             -21.7579     59.531     -0.365      0.715    -138.447      94.931
# neighbourhood_Jackson Heights                                           5.6897     39.378      0.144      0.885     -71.498      82.877
# neighbourhood_Jacob Riis Park-Fort Tilden-Breezy Point Tip             29.4062     81.915      0.359      0.720    -131.159     189.971
# neighbourhood_Jamaica                                                 -23.5525     43.483     -0.542      0.588    -108.786      61.681
# neighbourhood_Jamaica Estates-Holliswood                               50.9816     46.147      1.105      0.269     -39.473     141.437
# neighbourhood_Jamaica Hills-Briarwood                                 -25.0422     43.297     -0.578      0.563    -109.912      59.827
# neighbourhood_Kensington                                              112.6606     40.752      2.765      0.006      32.780     192.541
# neighbourhood_Kew Gardens                                              -4.3579     43.481     -0.100      0.920     -89.588      80.872
# neighbourhood_Kew Gardens Hills                                       -24.5609     43.962     -0.559      0.576    -110.733      61.611
# neighbourhood_Kingsbridge Heights-Van Cortlandt Village                -7.3862     54.383     -0.136      0.892    -113.985      99.213
# neighbourhood_Kingsbridge-Marble Hill                                 -36.4674     54.324     -0.671      0.502    -142.950      70.016
# neighbourhood_Laurelton                                               -77.6786     44.033     -1.764      0.078    -163.990       8.633
# neighbourhood_Lincoln Terrace Park                                    -16.1842     52.708     -0.307      0.759    -119.500      87.131
# neighbourhood_Long Island City-Hunters Point                           70.4342     40.143      1.755      0.079      -8.252     149.121
# neighbourhood_Longwood                                                  1.4835     70.181      0.021      0.983    -136.081     139.048
# neighbourhood_Madison                                                 -26.2856     41.183     -0.638      0.523    -107.010      54.439
# neighbourhood_Manhattanville-West Harlem                               40.7118     70.145      0.580      0.562     -96.783     178.206
# neighbourhood_Mapleton-Midwood (West)                                  20.7833     70.132      0.296      0.767    -116.685     158.252
# neighbourhood_Marine Park-Mill Basin-Bergen Beach                      18.9356     43.589      0.434      0.664     -66.506     104.377
# neighbourhood_Mariner's Harbor-Arlington-Graniteville                -119.2324     55.882     -2.134      0.033    -228.770      -9.695
# neighbourhood_Maspeth                                                 -58.4624     43.993     -1.329      0.184    -144.694      27.770
# neighbourhood_Melrose                                                  24.3523     51.235      0.475      0.635     -76.076     124.781
# neighbourhood_Middle Village                                           28.8322     46.545      0.619      0.536     -62.403     120.068
# neighbourhood_Middle Village Cemetery                                 -26.9025    108.661     -0.248      0.804    -239.894     186.090
# neighbourhood_Midwood                                                 -21.3992     40.886     -0.523      0.601    -101.542      58.743
# neighbourhood_Morris Park                                             -13.9829     47.075     -0.297      0.766    -106.257      78.291
# neighbourhood_Morrisania                                              -32.2645     47.655     -0.677      0.498    -125.676      61.147
# neighbourhood_Mott Haven-Port Morris                                   24.5440     40.734      0.603      0.547     -55.300     104.388
# neighbourhood_Mount Eden-Claremont (West)                             -24.0100     70.150     -0.342      0.732    -161.515     113.495
# neighbourhood_Mount Hope                                              -18.5542     42.328     -0.438      0.661    -101.522      64.414
# neighbourhood_Mount Olivet & All Faiths Cemeteries                    -12.4797     63.739     -0.196      0.845    -137.417     112.457
# neighbourhood_Murray Hill-Broadway Flushing                            30.0682     45.463      0.661      0.508     -59.047     119.183
# neighbourhood_New Dorp-Midland Beach                                  -75.6301     46.826     -1.615      0.106    -167.417      16.156
# neighbourhood_New Springville-Willowbrook-Bulls Head-Travis          -190.8519     73.021     -2.614      0.009    -333.984     -47.720
# neighbourhood_North Corona                                             -8.5890     41.127     -0.209      0.835     -89.203      72.025
# neighbourhood_Norwood                                                 -12.3164     56.571     -0.218      0.828    -123.203      98.571
# neighbourhood_Oakwood-Richmondtown                                    -94.7232     57.140     -1.658      0.097    -206.725      17.279
# neighbourhood_Ocean Hill                                                9.2428     39.054      0.237      0.813     -67.308      85.794
# neighbourhood_Old Astoria-Hallets Point                                 8.0419     41.434      0.194      0.846     -73.176      89.260
# neighbourhood_Ozone Park                                               14.3645     42.544      0.338      0.736     -69.029      97.758
# neighbourhood_Ozone Park (North)                                      -15.2620     49.212     -0.310      0.756    -111.724      81.200
# neighbourhood_Park Slope                                               68.2138     38.861      1.755      0.079      -7.960     144.388
# neighbourhood_Parkchester                                             -16.8514     54.369     -0.310      0.757    -123.423      89.720
# neighbourhood_Pelham Bay Park                                          63.9805     70.273      0.910      0.363     -73.764     201.725
# neighbourhood_Pelham Bay-Country Club-City Island                       2.0654     43.542      0.047      0.962     -83.284      87.414
# neighbourhood_Pelham Gardens                                          -11.0026     42.288     -0.260      0.795     -93.893      71.888
# neighbourhood_Pelham Parkway-Van Nest                                 -24.0741     56.542     -0.426      0.670    -134.906      86.758
# neighbourhood_Pomonok-Electchester-Hillcrest                          -13.1880     41.978     -0.314      0.753     -95.471      69.095
# neighbourhood_Port Richmond                                          -122.8074     49.595     -2.476      0.013    -220.021     -25.594
# neighbourhood_Prospect Heights                                         89.4053     39.370      2.271      0.023      12.234     166.577
# neighbourhood_Prospect Lefferts Gardens-Wingate                         5.9214     38.856      0.152      0.879     -70.242      82.085
# neighbourhood_Queens Village                                          -45.7669     42.026     -1.089      0.276    -128.145      36.611
# neighbourhood_Queensboro Hill                                         -10.7214     40.717     -0.263      0.792     -90.533      69.090
# neighbourhood_Queensbridge-Ravenswood-Dutch Kills                      41.0567     40.355      1.017      0.309     -38.046     120.159
# neighbourhood_Rego Park                                               -24.0541     42.690     -0.563      0.573    -107.732      59.624
# neighbourhood_Richmond Hill                                             5.5646     43.122      0.129      0.897     -78.962      90.091
# neighbourhood_Ridgewood                                                 0.0149     39.238      0.000      1.000     -76.897      76.927
# neighbourhood_Riverdale-Spuyten Duyvil                                118.6494     63.727      1.862      0.063      -6.264     243.563
# neighbourhood_Rockaway Beach-Arverne-Edgemere                          88.9493     39.261      2.266      0.023      11.992     165.907
# neighbourhood_Rockaway Community Park                                 -41.2162     70.157     -0.587      0.557    -178.733      96.301
# neighbourhood_Rosebank-Shore Acres-Park Hill                           -9.1765     46.521     -0.197      0.844    -100.365      82.012
# neighbourhood_Rosedale                                                -83.8260     44.712     -1.875      0.061    -171.468       3.816
# neighbourhood_Sheepshead Bay-Manhattan Beach-Gerritsen Beach           32.7875     41.260      0.795      0.427     -48.089     113.664
# neighbourhood_Soundview-Bruckner-Bronx River                           -4.4383     50.106     -0.089      0.929    -102.653      93.776
# neighbourhood_Soundview-Clason Point                                  -46.3187     43.539     -1.064      0.287    -131.661      39.024
# neighbourhood_South Jamaica                                           -30.6822     41.897     -0.732      0.464    -112.807      51.443
# neighbourhood_South Ozone Park                                         19.3219     41.391      0.467      0.641     -61.810     100.454
# neighbourhood_South Richmond Hill                                     -17.1257     46.614     -0.367      0.713    -108.496      74.245
# neighbourhood_South Williamsburg                                      186.0147     43.000      4.326      0.000     101.729     270.300
# neighbourhood_Spring Creek-Starrett City                                1.0177     56.836      0.018      0.986    -110.390     112.425
# neighbourhood_Springfield Gardens (North)-Rochdale Village            -42.9812     40.920     -1.050      0.294    -123.190      37.228
# neighbourhood_Springfield Gardens (South)-Brookville                  -62.3471     42.467     -1.468      0.142    -145.589      20.895
# neighbourhood_St. Albans                                              -12.8188     40.480     -0.317      0.752     -92.166      66.529
# neighbourhood_St. George-New Brighton                                 -73.3046     42.822     -1.712      0.087    -157.242      10.633
# neighbourhood_Sunnyside                                                24.0393     39.740      0.605      0.545     -53.857     101.936
# neighbourhood_Sunnyside Yards (South)                                  -2.1606     81.589     -0.026      0.979    -162.088     157.767
# neighbourhood_Sunset Park (Central)                                    24.9855     41.819      0.597      0.550     -56.987     106.958
# neighbourhood_Sunset Park (East)-Borough Park (West)                  -22.0391     70.209     -0.314      0.754    -159.659     115.580
# neighbourhood_Sunset Park (West)                                       22.9153     39.286      0.583      0.560     -54.091      99.922
# neighbourhood_Throgs Neck-Schuylerville                                -0.7385     43.559     -0.017      0.986     -86.120      84.643
# neighbourhood_Todt Hill-Emerson Hill-Lighthouse Hill-Manor Heights    -71.2780     73.140     -0.975      0.330    -214.643      72.087
# neighbourhood_Tompkinsville-Stapleton-Clifton-Fox Hills               -79.7875     42.760     -1.866      0.062    -163.604       4.029
# neighbourhood_Tottenville-Charleston                                 -276.6008     90.202     -3.066      0.002    -453.410     -99.791
# neighbourhood_Tremont                                                  27.1507     50.154      0.541      0.588     -71.158     125.460
# neighbourhood_University Heights (North)-Fordham                       -8.8504     47.131     -0.188      0.851    -101.234      83.534
# neighbourhood_University Heights (South)-Morris Heights                 7.1595     44.683      0.160      0.873     -80.426      94.745
# neighbourhood_Wakefield-Woodlawn                                      -19.5485     43.468     -0.450      0.653    -104.753      65.656
# neighbourhood_West New Brighton-Silver Lake-Grymes Hill               -99.9932     43.533     -2.297      0.022    -185.323     -14.663
# neighbourhood_Westchester Square                                        4.5798     54.400      0.084      0.933    -102.052     111.212
# neighbourhood_Westerleigh-Castleton Corners                          -115.4457     59.952     -1.926      0.054    -232.960       2.069
# neighbourhood_Whitestone-Beechhurst                                   -56.3174     54.906     -1.026      0.305    -163.941      51.306
# neighbourhood_Williamsbridge-Olinville                                 -0.9602     42.967     -0.022      0.982     -85.181      83.261
# neighbourhood_Williamsburg                                            110.2551     38.635      2.854      0.004      34.525     185.985
# neighbourhood_Windsor Terrace-South Slope                              29.1728     39.410      0.740      0.459     -48.078     106.423
# neighbourhood_Woodhaven                                               -10.1841     41.241     -0.247      0.805     -91.022      70.654
# neighbourhood_Woodside                                                 -2.7811     39.477     -0.070      0.944     -80.162      74.600
# neighbourhood_Yankee Stadium-Macombs Dam Park                         -44.6332     70.157     -0.636      0.525    -182.151      92.885
# ==============================================================================
# Omnibus:                    15795.475   Durbin-Watson:                   1.987
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          4460784.920
# Skew:                           6.203   Prob(JB):                         0.00
# Kurtosis:                      92.693   Cond. No.                     5.56e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.56e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# Taxi Distance

X5 = Xcreator(
    [
        "neighbourhood",
        "number_of_reviews",
        "review_scores_rating",
        "review_scores_accuracy",
        "review_scores_cleanliness",
        "review_scores_checkin",
        "review_scores_communication",
        "review_scores_location",
        "review_scores_value",
        "beds",
        "accommodates",
        "station_dist2",
        "park_dist2",
    ]
)
regress(Y, X5)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.470
# Model:                            OLS   Adj. R-squared:                  0.463
# Method:                 Least Squares   F-statistic:                     60.49
# Date:                Fri, 13 May 2022   Prob (F-statistic):               0.00
# Time:                        00:22:00   Log-Likelihood:                -78778.
# No. Observations:               13058   AIC:                         1.579e+05
# Df Residuals:                   12868   BIC:                         1.594e+05
# Df Model:                         189
# Covariance Type:            nonrobust
# =======================================================================================================================================
#                                                                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------------------------------
# const                                                                  14.6184     43.568      0.336      0.737     -70.782     100.019
# number_of_reviews                                                      -0.1865      0.013    -14.911      0.000      -0.211      -0.162
# review_scores_rating                                                   57.9415      6.767      8.562      0.000      44.676      71.207
# review_scores_accuracy                                                 12.1666      6.722      1.810      0.070      -1.009      25.342
# review_scores_cleanliness                                              15.8666      4.291      3.698      0.000       7.456      24.277
# review_scores_checkin                                                 -35.9653      6.067     -5.928      0.000     -47.858     -24.072
# review_scores_communication                                           -15.5640      6.437     -2.418      0.016     -28.182      -2.946
# review_scores_location                                                 16.4422      4.565      3.602      0.000       7.494      25.390
# review_scores_value                                                   -53.1437      5.938     -8.949      0.000     -64.784     -41.504
# beds                                                                   14.7118      0.941     15.639      0.000      12.868      16.556
# accommodates                                                           28.7183      0.618     46.454      0.000      27.507      29.930
# station_dist2                                                          13.3543      3.380      3.951      0.000       6.729      19.980
# park_dist2                                                              0.2232      3.135      0.071      0.943      -5.921       6.368
# neighbourhood_Annadale-Huguenot-Prince's Bay-Woodrow                 -140.3098     81.346     -1.725      0.085    -299.759      19.140
# neighbourhood_Arden Heights-Rossville                                -231.0967     79.230     -2.917      0.004    -386.398     -75.795
# neighbourhood_Astoria (Central)                                        10.1310     39.136      0.259      0.796     -66.582      86.844
# neighbourhood_Astoria (East)-Woodside (North)                          13.1391     39.579      0.332      0.740     -64.442      90.720
# neighbourhood_Astoria (North)-Ditmars-Steinway                         21.4214     39.455      0.543      0.587     -55.915      98.758
# neighbourhood_Astoria Park                                             51.6992     81.532      0.634      0.526    -108.116     211.515
# neighbourhood_Auburndale                                              -50.1112     43.995     -1.139      0.255    -136.347      36.125
# neighbourhood_Baisley Park                                            -26.8208     40.090     -0.669      0.504    -105.404      51.763
# neighbourhood_Bath Beach                                               -0.1522     42.956     -0.004      0.997     -84.353      84.049
# neighbourhood_Bay Ridge                                               -19.8791     39.557     -0.503      0.615     -97.416      57.658
# neighbourhood_Bay Terrace-Clearview                                   316.8469     61.784      5.128      0.000     195.742     437.952
# neighbourhood_Bayside                                                  -6.4225     45.823     -0.140      0.889     -96.241      83.396
# neighbourhood_Bedford Park                                             17.2952     49.168      0.352      0.725     -79.082     113.672
# neighbourhood_Bedford-Stuyvesant (East)                                23.1588     38.589      0.600      0.548     -52.481      98.799
# neighbourhood_Bedford-Stuyvesant (West)                                38.8935     38.610      1.007      0.314     -36.787     114.574
# neighbourhood_Bellerose                                               -94.1475     65.463     -1.438      0.150    -222.465      34.170
# neighbourhood_Belmont                                                 -33.2961     50.138     -0.664      0.507    -131.575      64.983
# neighbourhood_Bensonhurst                                             -32.5159     41.765     -0.779      0.436    -114.382      49.350
# neighbourhood_Borough Park                                            -33.4572     70.168     -0.477      0.633    -170.996     104.082
# neighbourhood_Breezy Point-Belle Harbor-Rockaway Park-Broad Channel   101.3067     51.264      1.976      0.048       0.822     201.792
# neighbourhood_Brighton Beach                                           48.8227     42.691      1.144      0.253     -34.858     132.503
# neighbourhood_Brooklyn Heights                                        222.9010     41.194      5.411      0.000     142.155     303.647
# neighbourhood_Brooklyn Navy Yard                                       96.4737     81.520      1.183      0.237     -63.318     256.266
# neighbourhood_Brownsville                                              -4.0261     41.745     -0.096      0.923     -85.852      77.800
# neighbourhood_Bushwick (East)                                          10.0033     38.771      0.258      0.796     -65.993      86.000
# neighbourhood_Bushwick (West)                                          21.7567     38.796      0.561      0.575     -54.290      97.803
# neighbourhood_Calvary & Mount Zion Cemeteries                         -25.0734     70.265     -0.357      0.721    -162.803     112.656
# neighbourhood_Cambria Heights                                         -62.4926     50.150     -1.246      0.213    -160.795      35.810
# neighbourhood_Canarsie                                                -15.0409     39.250     -0.383      0.702     -91.977      61.896
# neighbourhood_Canarsie Park & Pier                                     -1.8559     52.839     -0.035      0.972    -105.427     101.716
# neighbourhood_Carroll Gardens-Cobble Hill-Gowanus-Red Hook             91.9448     38.779      2.371      0.018      15.932     167.958
# neighbourhood_Castle Hill-Unionport                                   -67.6814    108.657     -0.623      0.533    -280.665     145.302
# neighbourhood_Clinton Hill                                             79.6465     39.035      2.040      0.041       3.132     156.161
# neighbourhood_Co-op City                                              -24.8595     63.762     -0.390      0.697    -149.842     100.123
# neighbourhood_College Point                                           -36.8309     45.056     -0.817      0.414    -125.147      51.485
# neighbourhood_Concourse-Concourse Village                              -9.7475     41.151     -0.237      0.813     -90.410      70.915
# neighbourhood_Coney Island-Sea Gate                                    67.7890     43.586      1.555      0.120     -17.645     153.223
# neighbourhood_Corona                                                   -4.8665     40.385     -0.121      0.904     -84.028      74.294
# neighbourhood_Crotona Park East                                         1.7708     49.161      0.036      0.971     -94.592      98.134
# neighbourhood_Crown Heights (North)                                    18.2615     38.691      0.472      0.637     -57.579      94.102
# neighbourhood_Crown Heights (South)                                    -2.4547     39.778     -0.062      0.951     -80.426      75.516
# neighbourhood_Cypress Hills                                             1.2045     39.754      0.030      0.976     -76.720      79.129
# neighbourhood_Douglaston-Little Neck                                  -91.8110     58.240     -1.576      0.115    -205.971      22.349
# neighbourhood_Downtown Brooklyn-DUMBO-Boerum Hill                     127.8100     39.516      3.234      0.001      50.353     205.267
# neighbourhood_Dyker Heights                                           -56.6576     56.551     -1.002      0.316    -167.507      54.191
# neighbourhood_East Elmhurst                                           -29.7583     39.660     -0.750      0.453    -107.498      47.981
# neighbourhood_East Flatbush-Erasmus                                    -1.3975     39.344     -0.036      0.972     -78.517      75.722
# neighbourhood_East Flatbush-Farragut                                   -8.9760     40.369     -0.222      0.824     -88.105      70.153
# neighbourhood_East Flatbush-Remsen Village                             -9.9973     40.772     -0.245      0.806     -89.917      69.923
# neighbourhood_East Flatbush-Rugby                                     -23.4657     40.189     -0.584      0.559    -102.241      55.310
# neighbourhood_East Flushing                                           -33.7341     41.561     -0.812      0.417    -115.201      47.733
# neighbourhood_East Midtown-Turtle Bay                                 568.3176     52.214     10.884      0.000     465.970     670.666
# neighbourhood_East New York (North)                                    -8.8572     39.553     -0.224      0.823     -86.387      68.673
# neighbourhood_East New York-City Line                                 -27.7340     40.984     -0.677      0.499    -108.069      52.601
# neighbourhood_East New York-New Lots                                   -4.9284     39.305     -0.125      0.900     -81.972      72.115
# neighbourhood_East Williamsburg                                        68.2911     38.731      1.763      0.078      -7.627     144.209
# neighbourhood_Eastchester-Edenwald-Baychester                         -41.3530     41.993     -0.985      0.325    -123.666      40.960
# neighbourhood_Elmhurst                                                 -9.7843     39.669     -0.247      0.805     -87.541      67.973
# neighbourhood_Far Rockaway-Bayswater                                    9.3778     40.613      0.231      0.817     -70.230      88.986
# neighbourhood_Financial District-Battery Park City                    329.7613     70.219      4.696      0.000     192.121     467.401
# neighbourhood_Flatbush                                                  6.1513     39.449      0.156      0.876     -71.175      83.478
# neighbourhood_Flatbush (West)-Ditmas Park-Parkville                    16.1359     39.665      0.407      0.684     -61.613      93.884
# neighbourhood_Flatlands                                                30.9838     40.158      0.772      0.440     -47.731     109.699
# neighbourhood_Flushing-Willets Point                                  -17.0338     40.089     -0.425      0.671     -95.615      61.547
# neighbourhood_Fordham Heights                                          -9.6396     52.635     -0.183      0.855    -112.812      93.533
# neighbourhood_Forest Hills                                             49.0461     39.751      1.234      0.217     -28.871     126.963
# neighbourhood_Fort Greene                                              71.0842     39.120      1.817      0.069      -5.597     147.766
# neighbourhood_Fresh Meadows-Utopia                                     20.9010     43.914      0.476      0.634     -65.177     106.979
# neighbourhood_Glendale                                                -29.9145     44.409     -0.674      0.501    -116.963      57.134
# neighbourhood_Grasmere-Arrochar-South Beach-Dongan Hills              -77.8029     43.141     -1.803      0.071    -162.365       6.759
# neighbourhood_Gravesend (East)-Homecrest                               -6.5535     41.572     -0.158      0.875     -88.042      74.935
# neighbourhood_Gravesend (South)                                         5.0382     51.296      0.098      0.922     -95.509     105.586
# neighbourhood_Gravesend (West)                                        -14.6128     43.493     -0.336      0.737     -99.866      70.640
# neighbourhood_Great Kills-Eltingville                                -198.7933     63.999     -3.106      0.002    -324.241     -73.346
# neighbourhood_Greenpoint                                              104.9537     38.915      2.697      0.007      28.674     181.234
# neighbourhood_Hamilton Heights-Sugar Hill                              85.2035     70.174      1.214      0.225     -52.347     222.754
# neighbourhood_Highbridge                                               -1.6539     50.195     -0.033      0.974    -100.044      96.737
# neighbourhood_Hollis                                                  -12.5137     42.492     -0.294      0.768     -95.805      70.777
# neighbourhood_Holy Cross Cemetery                                     -25.3905     56.728     -0.448      0.654    -136.586      85.805
# neighbourhood_Howard Beach-Lindenwood                                  26.5416     43.704      0.607      0.544     -59.125     112.208
# neighbourhood_Hunts Point                                             -21.8775     59.548     -0.367      0.713    -138.601      94.846
# neighbourhood_Jackson Heights                                           3.8392     39.402      0.097      0.922     -73.394      81.072
# neighbourhood_Jacob Riis Park-Fort Tilden-Breezy Point Tip             25.9796     82.066      0.317      0.752    -134.883     186.842
# neighbourhood_Jamaica                                                 -23.2027     43.497     -0.533      0.594    -108.463      62.058
# neighbourhood_Jamaica Estates-Holliswood                               50.1797     46.165      1.087      0.277     -40.310     140.670
# neighbourhood_Jamaica Hills-Briarwood                                 -26.4731     43.319     -0.611      0.541    -111.384      58.438
# neighbourhood_Kensington                                              114.1056     40.759      2.800      0.005      34.213     193.998
# neighbourhood_Kew Gardens                                              -3.0693     43.492     -0.071      0.944     -88.319      82.180
# neighbourhood_Kew Gardens Hills                                       -22.6412     43.945     -0.515      0.606    -108.780      63.497
# neighbourhood_Kingsbridge Heights-Van Cortlandt Village                -4.9640     54.389     -0.091      0.927    -111.575     101.647
# neighbourhood_Kingsbridge-Marble Hill                                 -35.2288     54.340     -0.648      0.517    -141.743      71.286
# neighbourhood_Laurelton                                               -82.9298     44.438     -1.866      0.062    -170.035       4.176
# neighbourhood_Lincoln Terrace Park                                    -12.8423     52.709     -0.244      0.808    -116.161      90.476
# neighbourhood_Long Island City-Hunters Point                           70.8606     40.156      1.765      0.078      -7.851     149.573
# neighbourhood_Longwood                                                 -0.3338     70.201     -0.005      0.996    -137.938     137.270
# neighbourhood_Madison                                                 -27.8215     41.202     -0.675      0.500    -108.584      52.942
# neighbourhood_Manhattanville-West Harlem                               43.1919     70.154      0.616      0.538     -94.321     180.705
# neighbourhood_Mapleton-Midwood (West)                                  19.3496     70.153      0.276      0.783    -118.160     156.859
# neighbourhood_Marine Park-Mill Basin-Bergen Beach                      19.8575     43.543      0.456      0.648     -65.493     105.208
# neighbourhood_Mariner's Harbor-Arlington-Graniteville                -118.6159     54.796     -2.165      0.030    -226.023     -11.209
# neighbourhood_Maspeth                                                 -56.1596     43.962     -1.277      0.201    -142.332      30.013
# neighbourhood_Melrose                                                  25.2513     51.247      0.493      0.622     -75.200     125.703
# neighbourhood_Middle Village                                           30.5310     46.550      0.656      0.512     -60.714     121.776
# neighbourhood_Middle Village Cemetery                                 -27.0223    108.681     -0.249      0.804    -240.052     186.008
# neighbourhood_Midwood                                                 -23.0478     40.901     -0.564      0.573    -103.220      57.124
# neighbourhood_Morris Park                                             -13.7436     47.085     -0.292      0.770    -106.038      78.550
# neighbourhood_Morrisania                                              -33.1236     47.664     -0.695      0.487    -126.552      60.304
# neighbourhood_Mott Haven-Port Morris                                   26.1234     40.743      0.641      0.521     -53.738     105.985
# neighbourhood_Mount Eden-Claremont (West)                             -21.3413     70.162     -0.304      0.761    -158.870     116.187
# neighbourhood_Mount Hope                                              -16.5454     42.338     -0.391      0.696     -99.535      66.444
# neighbourhood_Mount Olivet & All Faiths Cemeteries                    -12.8445     63.749     -0.201      0.840    -137.803     112.114
# neighbourhood_Murray Hill-Broadway Flushing                            27.3276     45.466      0.601      0.548     -61.792     116.448
# neighbourhood_New Dorp-Midland Beach                                  -85.9478     48.328     -1.778      0.075    -180.678       8.783
# neighbourhood_New Springville-Willowbrook-Bulls Head-Travis          -191.1118     73.821     -2.589      0.010    -335.811     -46.412
# neighbourhood_North Corona                                             -9.9203     41.147     -0.241      0.809     -90.574      70.734
# neighbourhood_Norwood                                                  -9.7287     56.576     -0.172      0.863    -120.627     101.170
# neighbourhood_Oakwood-Richmondtown                                   -108.9595     59.239     -1.839      0.066    -225.077       7.158
# neighbourhood_Ocean Hill                                                6.4755     39.066      0.166      0.868     -70.099      83.050
# neighbourhood_Old Astoria-Hallets Point                                 8.8518     41.442      0.214      0.831     -72.381      90.084
# neighbourhood_Ozone Park                                               13.7181     42.564      0.322      0.747     -69.714      97.150
# neighbourhood_Ozone Park (North)                                      -19.6124     49.245     -0.398      0.690    -116.140      76.915
# neighbourhood_Park Slope                                               68.3777     38.875      1.759      0.079      -7.822     144.578
# neighbourhood_Parkchester                                             -19.8423     54.401     -0.365      0.715    -126.477      86.792
# neighbourhood_Pelham Bay Park                                          65.1988     70.286      0.928      0.354     -72.573     202.970
# neighbourhood_Pelham Bay-Country Club-City Island                       0.2663     43.560      0.006      0.995     -85.118      85.650
# neighbourhood_Pelham Gardens                                          -10.0899     42.296     -0.239      0.811     -92.996      72.816
# neighbourhood_Pelham Parkway-Van Nest                                 -24.5677     56.558     -0.434      0.664    -135.431      86.295
# neighbourhood_Pomonok-Electchester-Hillcrest                          -11.2016     41.890     -0.267      0.789     -93.312      70.909
# neighbourhood_Port Richmond                                          -116.7469     49.102     -2.378      0.017    -212.994     -20.500
# neighbourhood_Prospect Heights                                         90.7686     39.379      2.305      0.021      13.580     167.957
# neighbourhood_Prospect Lefferts Gardens-Wingate                         6.4375     38.867      0.166      0.868     -69.747      82.622
# neighbourhood_Queens Village                                          -52.4891     41.995     -1.250      0.211    -134.805      29.827
# neighbourhood_Queensboro Hill                                          -6.0450     40.670     -0.149      0.882     -85.765      73.675
# neighbourhood_Queensbridge-Ravenswood-Dutch Kills                      40.3798     40.373      1.000      0.317     -38.758     119.518
# neighbourhood_Rego Park                                               -26.1286     42.721     -0.612      0.541    -109.869      57.612
# neighbourhood_Richmond Hill                                             5.5485     43.137      0.129      0.898     -79.007      90.104
# neighbourhood_Ridgewood                                                -3.6724     39.276     -0.094      0.926     -80.659      73.314
# neighbourhood_Riverdale-Spuyten Duyvil                                121.6487     63.736      1.909      0.056      -3.283     246.580
# neighbourhood_Rockaway Beach-Arverne-Edgemere                          91.0966     39.267      2.320      0.020      14.127     168.067
# neighbourhood_Rockaway Community Park                                 -38.0369     70.172     -0.542      0.588    -175.585      99.511
# neighbourhood_Rosebank-Shore Acres-Park Hill                          -14.5775     46.472     -0.314      0.754    -105.669      76.514
# neighbourhood_Rosedale                                                -78.2883     44.306     -1.767      0.077    -165.135       8.559
# neighbourhood_Sheepshead Bay-Manhattan Beach-Gerritsen Beach           32.5779     41.268      0.789      0.430     -48.313     113.469
# neighbourhood_Soundview-Bruckner-Bronx River                           -2.7906     50.114     -0.056      0.956    -101.022      95.441
# neighbourhood_Soundview-Clason Point                                  -37.8229     43.401     -0.871      0.384    -122.895      47.249
# neighbourhood_South Jamaica                                           -30.2682     41.880     -0.723      0.470    -112.360      51.823
# neighbourhood_South Ozone Park                                         10.9830     41.421      0.265      0.791     -70.208      92.174
# neighbourhood_South Richmond Hill                                     -21.7822     46.678     -0.467      0.641    -113.279      69.714
# neighbourhood_South Williamsburg                                      182.5110     43.011      4.243      0.000      98.203     266.819
# neighbourhood_Spring Creek-Starrett City                                2.7093     56.839      0.048      0.962    -108.703     114.121
# neighbourhood_Springfield Gardens (North)-Rochdale Village            -37.7897     40.713     -0.928      0.353    -117.593      42.014
# neighbourhood_Springfield Gardens (South)-Brookville                  -51.1475     41.766     -1.225      0.221    -133.016      30.721
# neighbourhood_St. Albans                                              -18.0306     40.652     -0.444      0.657     -97.715      61.653
# neighbourhood_St. George-New Brighton                                 -76.1408     42.922     -1.774      0.076    -160.273       7.992
# neighbourhood_Sunnyside                                                17.6027     39.843      0.442      0.659     -60.496      95.701
# neighbourhood_Sunnyside Yards (South)                                  -9.7261     81.650     -0.119      0.905    -169.772     150.320
# neighbourhood_Sunset Park (Central)                                    27.1513     41.825      0.649      0.516     -54.831     109.134
# neighbourhood_Sunset Park (East)-Borough Park (West)                  -22.5250     70.226     -0.321      0.748    -160.179     115.129
# neighbourhood_Sunset Park (West)                                       22.0652     39.303      0.561      0.575     -54.974      99.105
# neighbourhood_Throgs Neck-Schuylerville                                -2.0832     43.569     -0.048      0.962     -87.486      83.319
# neighbourhood_Todt Hill-Emerson Hill-Lighthouse Hill-Manor Heights    -82.6708     73.994     -1.117      0.264    -227.710      62.368
# neighbourhood_Tompkinsville-Stapleton-Clifton-Fox Hills               -78.3746     42.646     -1.838      0.066    -161.968       5.219
# neighbourhood_Tottenville-Charleston                                 -308.5897     97.136     -3.177      0.001    -498.990    -118.189
# neighbourhood_Tremont                                                  31.0650     50.151      0.619      0.536     -67.238     129.368
# neighbourhood_University Heights (North)-Fordham                       -6.2608     47.138     -0.133      0.894     -98.659      86.137
# neighbourhood_University Heights (South)-Morris Heights                 8.4727     44.688      0.190      0.850     -79.122      96.068
# neighbourhood_Wakefield-Woodlawn                                      -20.2292     43.480     -0.465      0.642    -105.456      64.997
# neighbourhood_West New Brighton-Silver Lake-Grymes Hill               -95.2131     43.308     -2.199      0.028    -180.103     -10.324
# neighbourhood_Westchester Square                                       -0.9482     54.378     -0.017      0.986    -107.538     105.642
# neighbourhood_Westerleigh-Castleton Corners                          -109.7221     59.161     -1.855      0.064    -225.686       6.242
# neighbourhood_Whitestone-Beechhurst                                   -51.6161     54.799     -0.942      0.346    -159.030      55.798
# neighbourhood_Williamsbridge-Olinville                                  0.4824     42.974      0.011      0.991     -83.754      84.718
# neighbourhood_Williamsburg                                            109.8865     38.647      2.843      0.004      34.133     185.640
# neighbourhood_Windsor Terrace-South Slope                              30.5444     39.416      0.775      0.438     -46.717     107.806
# neighbourhood_Woodhaven                                                -8.4586     41.252     -0.205      0.838     -89.319      72.402
# neighbourhood_Woodside                                                 -5.2553     39.500     -0.133      0.894     -82.682      72.171
# neighbourhood_Yankee Stadium-Macombs Dam Park                         -41.3447     70.167     -0.589      0.556    -178.882      96.192
# ==============================================================================
# Omnibus:                    15800.917   Durbin-Watson:                   1.987
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          4473044.614
# Skew:                           6.206   Prob(JB):                         0.00
# Kurtosis:                      92.818   Cond. No.                     5.56e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.56e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# /Users/steven_unique/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %% [markdown]
# Linear distance seems to be a better indicator than taxi distance.
#
# Next, we find the RMSE of the best regression (so price on neighbourhoods and controls including linear distances)

# %%
model = LinearRegression()
model.fit(X4, Y)
X_predict = X4
Y_predict = model.predict(X_predict)
rmse = mean_squared_error(Y, Y_predict, squared=False)
rmse
# Out:
# 100.8644758561287
