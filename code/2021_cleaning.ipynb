# %%
# Libraries set-up

# %load_ext lab_black
import os
import numpy as np
import pandas as pd
from sklearn import linear_model
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm
from scipy import stats
import matplotlib.pyplot as plt
from PIL import Image

# %%
# Import data

data_2021 = pd.read_csv("../data/newnh_airbnb_2021.csv")

# %%
# Keep interesting subset of columns for all analyses, drop empty rows

data = data_2021[
    [
        "price",
        "neighbourhood",
        "neighbourhood_group",
        "room_type",
        "number_of_reviews",
        "reviews_per_month",
        "calculated_host_listings_count",
        "number_of_reviews_ltm",
    ]
]
data = data.dropna()

# %%
# Set up price as Y (dependent variable) for all regressions

Y = data["price"]

# %%
# Set up data for simple linear regression of price on neighborhood group, Bronx used as baseline

datang = data[
    [
        "price",
        "neighbourhood_group",
    ]
]
datang = pd.get_dummies(datang, columns=["neighbourhood_group"])
datang.drop(["neighbourhood_group_Bronx"], axis=1, inplace=True)
datang.astype(float)

Xng = datang
datang.drop(["price"], axis=1, inplace=True)
XngC = sm.add_constant(Xng)

# %%
# Run Linear regression of price on neighborhood group dummies

estng = sm.OLS(Y, XngC)
est_ng = estng.fit()
est_ng.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.016
# Model:                            OLS   Adj. R-squared:                  0.016
# Method:                 Least Squares   F-statistic:                     110.6
# Date:                Thu, 12 May 2022   Prob (F-statistic):           1.16e-93
# Time:                        06:58:12   Log-Likelihood:            -1.9348e+05
# No. Observations:               27627   AIC:                         3.870e+05
# Df Residuals:                   27622   BIC:                         3.870e+05
# Df Model:                           4
# Covariance Type:            nonrobust
# =====================================================================================================
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# const                                94.8289      9.515      9.966      0.000      76.178     113.480
# neighbourhood_group_Brooklyn         43.7167      9.841      4.442      0.000      24.427      63.006
# neighbourhood_group_Manhattan        99.6544      9.832     10.135      0.000      80.382     118.926
# neighbourhood_group_Queens           17.6429     10.458      1.687      0.092      -2.855      38.141
# neighbourhood_group_Staten Island     8.3145     18.740      0.444      0.657     -28.417      45.046
# ==============================================================================
# Omnibus:                    63756.943   Durbin-Watson:                   1.847
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):        641016693.598
# Skew:                          22.579   Prob(JB):                         0.00
# Kurtosis:                     747.864   Cond. No.                         17.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# Exporting image of the above results

plt.rc("figure", figsize=(16 / 1.5, 10 / 1.5), dpi=900)
plt.text(0.01, 0.05, str(est_ng.summary()), {"fontsize": 9}, fontproperties="monospace")
plt.axis("off")
plt.tight_layout()
os.makedirs("../artifacts", exist_ok=True)
plt.savefig("../artifacts/reg1.jpeg")

# %%
# Set up data for simple linear regression of price on neighborhood, Midtown used as baseline

datan = data[
    [
        "price",
        "neighbourhood",
    ]
]
datan = pd.get_dummies(datan, columns=["neighbourhood"])
datan.drop(["neighbourhood_Midtown"], axis=1, inplace=True)
datan.astype(float)

Xn = datan
datan.drop(["price"], axis=1, inplace=True)
XnC = sm.add_constant(Xn)

# %%
# Run Linear regression of price on neighborhood group dummies

estn = sm.OLS(Y, XnC)
est_n = estn.fit()
est_n.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.042
# Model:                            OLS   Adj. R-squared:                  0.034
# Method:                 Least Squares   F-statistic:                     5.461
# Date:                Thu, 12 May 2022   Prob (F-statistic):          4.16e-131
# Time:                        06:58:24   Log-Likelihood:            -1.9311e+05
# No. Observations:               27627   AIC:                         3.867e+05
# Df Residuals:                   27406   BIC:                         3.885e+05
# Df Model:                         220
# Covariance Type:            nonrobust
# ===========================================================================================================
#                                               coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------
# const                
# neighbourhood_Flushing                   -164.2118     17.502     -9.382      0.000    -198.517    -129.906
# neighbourhood_Fordham                    -184.6591     46.721     -3.952      0.000    -276.235     -93.084
# neighbourhood_Forest Hills               -120.2809     30.560     -3.936      0.000    -180.180     -60.382
# neighbourhood_Fort Greene                 -75.5995     18.015     -4.196      0.000    -110.911     -40.288
# neighbourhood_Fort Hamilton              -153.2500     47.421     -3.232      0.001    -246.197     -60.303
# neighbourhood_Fresh Meadows              -145.6591     46.721     -3.118      0.002    -237.235     -54.084
# neighbourhood_Glen Oaks                  -187.7500    263.866     -0.712      0.477    -704.941     329.441
# neighbourhood_Glendale                   -184.6548     41.608     -4.438      0.000    -266.209    -103.101
# neighbourhood_Gowanus                     -51.1515     24.539     -2.084      0.037     -99.249      -3.054
# neighbourhood_Gramercy                    -65.9752     23.149     -2.850      0.004    -111.348     -20.602
# neighbourhood_Graniteville               -217.2500    186.682     -1.164      0.245    -583.157     148.657
# neighbourhood_Grant City                 -200.5833     76.623     -2.618      0.009    -350.769     -50.398
# neighbourhood_Gravesend                  -155.5793     42.091     -3.696      0.000    -238.079     -73.080
# neighbourhood_Great Kills                -143.2500    132.147     -1.084      0.278    -402.265     115.765
# neighbourhood_Greenpoint                  -78.1248     13.920     -5.613      0.000    -105.408     -50.842
# neighbourhood_Greenwich Village           -28.9222     21.486     -1.346      0.178     -71.036      13.192
# neighbourhood_Grymes Hill                 -82.2500    108.014     -0.761      0.446    -293.962     129.462
# neighbourhood_Harlem                     -141.3804     11.008    -12.843      0.000    -162.957    -119.804
# neighbourhood_Hell's Kitchen              -46.7431     12.011     -3.892      0.000     -70.286     -23.200
# neighbourhood_Highbridge                 -183.1389     62.763     -2.918      0.004    -306.157     -60.121
# neighbourhood_Hollis                     -185.0577     73.657     -2.512      0.012    -329.428     -40.687
# neighbourhood_Holliswood                 -174.2500    132.147     -1.319      0.187    -433.265      84.765
# neighbourhood_Howard Beach               -110.9853     64.548     -1.719      0.086    -237.503      15.532
# neighbourhood_Howland Hook               -124.2500    186.682     -0.666      0.506    -490.157     241.657
# neighbourhood_Huguenot                   -170.0833    152.508     -1.115      0.265    -469.007     128.840
# neighbourhood_Hunts Point                -211.3000     59.605     -3.545      0.000    -328.129     -94.471
# neighbourhood_Inwood                     -178.4983     23.699     -7.532      0.000    -224.949    -132.047
# neighbourhood_Jackson Heights            -179.9737     23.083     -7.797      0.000    -225.218    -134.729
# neighbourhood_Jamaica                    -155.3278     21.486     -7.229      0.000    -197.442    -113.214
# neighbourhood_Jamaica Estates             -91.2500     66.499     -1.372      0.170    -221.592      39.092
# neighbourhood_Jamaica Hills              -149.9167    108.014     -1.388      0.165    -361.629      61.796
# neighbourhood_Kensington                 -112.2944     29.121     -3.856      0.000    -169.374     -55.215
# neighbourhood_Kew Gardens                -173.2955     56.891     -3.046      0.002    -284.806     -61.785
# neighbourhood_Kew Gardens Hills          -154.4500     59.605     -2.591      0.010    -271.279     -37.621
# neighbourhood_Kingsbridge                -177.8690     41.608     -4.275      0.000    -259.423     -96.315
# neighbourhood_Kips Bay                    -80.5508     18.350     -4.390      0.000    -116.518     -44.583
# neighbourhood_Laurelton                  -162.1944     51.490     -3.150      0.002    -263.117     -61.272
# neighbourhood_Lighthouse Hill            -112.7500    263.866     -0.427      0.669    -629.941     404.441
# neighbourhood_Little Italy                -90.9038     31.096     -2.923      0.003    -151.853     -29.955
# neighbourhood_Little Neck                -199.4167    152.508     -1.308      0.191    -498.340      99.507
# neighbourhood_Long Island City            -86.1904     17.481     -4.931      0.000    -120.453     -51.928
# neighbourhood_Longwood                   -167.4470     46.721     -3.584      0.000    -259.022     -75.871
# neighbourhood_Lower East Side             -19.2404     14.458     -1.331      0.183     -47.578       9.097
# neighbourhood_Manhattan Beach            -154.2500    108.014     -1.428      0.153    -365.962      57.462
# neighbourhood_Marble Hill                -175.9722     88.335     -1.992      0.046    -349.113      -2.831
# neighbourhood_Mariners Harbor            -179.5000     93.643     -1.917      0.055    -363.045       4.045
# neighbourhood_Maspeth                    -173.6423     33.842     -5.131      0.000    -239.974    -107.311
# neighbourhood_Melrose                    -192.7500     83.847     -2.299      0.022    -357.094     -28.406
# neighbourhood_Middle Village             -128.4773     56.891     -2.258      0.024    -239.987     -16.967
# neighbourhood_Midland Beach              -132.5500    118.259     -1.121      0.262    -364.345      99.245
# neighbourhood_Midwood                    -177.7661     34.598     -5.138      0.000    -245.581    -109.952
# neighbourhood_Mill Basin                 -166.2500    108.014     -1.539      0.124    -377.962      45.462
# neighbourhood_Morningside Heights        -152.1043     21.742     -6.996      0.000    -194.719    -109.490
# neighbourhood_Morris Heights             -125.8214     71.015     -1.772      0.076    -265.015      13.372
# neighbourhood_Morris Park                -183.6974     61.121     -3.005      0.003    -303.498     -63.897
# neighbourhood_Morrisania                 -185.8500     83.847     -2.217      0.027    -350.194     -21.506
# neighbourhood_Mott Haven                 -159.6786     41.608     -3.838      0.000    -241.232     -78.125
# neighbourhood_Mount Eden                 -203.2500    132.147     -1.538      0.124    -462.265      55.765
# neighbourhood_Mount Hope                 -177.1250     54.527     -3.248      0.001    -284.001     -70.249
# neighbourhood_Murray Hill                 -25.3345     19.820     -1.278      0.201     -64.184      13.515
# neighbourhood_Navy Yard                   -83.4167    152.508     -0.547      0.584    -382.340     215.507
# neighbourhood_Neponsit                    -62.7500    263.866     -0.238      0.812    -579.941     454.441
# neighbourhood_New Brighton               -176.4643    100.055     -1.764      0.078    -372.577      19.649
# neighbourhood_New Dorp                    -87.7500    263.866     -0.333      0.739    -604.941     429.441
# neighbourhood_New Dorp Beach             -167.2500    132.147     -1.266      0.206    -426.265      91.765
# neighbourhood_New Springville            -102.2500    186.682     -0.548      0.584    -468.157     263.657
# neighbourhood_NoHo                        -34.8712     46.721     -0.746      0.455    -126.447      56.704
# neighbourhood_Nolita                      -68.7500     24.704     -2.783      0.005    -117.170     -20.330
# neighbourhood_North Riverdale            -178.8929    100.055     -1.788      0.074    -375.006      17.220
# neighbourhood_Norwood                    -184.1944     62.763     -2.935      0.003    -307.213     -61.176
# neighbourhood_Oakwood                     -99.0357    100.055     -0.990      0.322    -295.149      97.077
# neighbourhood_Olinville                  -113.4167     88.335     -1.284      0.199    -286.558      59.724
# neighbourhood_Ozone Park                 -164.3722     40.260     -4.083      0.000    -243.283     -85.462
# neighbourhood_Park Slope                  -87.5056     18.350     -4.769      0.000    -123.473     -51.538
# neighbourhood_Parkchester                -172.0300     53.454     -3.218      0.001    -276.802     -67.258
# neighbourhood_Pelham Bay                 -105.0833     88.335     -1.190      0.234    -278.224      68.058
# neighbourhood_Pelham Gardens             -169.4891     55.670     -3.045      0.002    -278.606     -60.372
# neighbourhood_Port Morris                -155.4000     59.605     -2.607      0.009    -272.229     -38.571
# neighbourhood_Port Richmond              -202.8929    100.055     -2.028      0.043    -399.006      -6.780
# neighbourhood_Prince's Bay               -117.7500    263.866     -0.446      0.655    -634.941     399.441
# neighbourhood_Prospect Heights            -95.4674     21.290     -4.484      0.000    -137.197     -53.738
# neighbourhood_Prospect-Lefferts Gardens  -147.5818     16.969     -8.697      0.000    -180.843    -114.321
# neighbourhood_Queens Village             -129.3587     39.840     -3.247      0.001    -207.447     -51.270
# neighbourhood_Randall Manor              -194.8611     88.335     -2.206      0.027    -368.002     -21.720
# neighbourhood_Red Hook                    -81.6557     37.250     -2.192      0.028    -154.667      -8.644
# neighbourhood_Rego Park                  -127.1568     35.413     -3.591      0.000    -196.568     -57.745
# neighbourhood_Richmond Hill              -153.6471     33.137     -4.637      0.000    -218.597     -88.697
# neighbourhood_Richmondtown               -176.2500    186.682     -0.944      0.345    -542.157     189.657
# neighbourhood_Ridgewood                  -156.2173     20.610     -7.580      0.000    -196.614    -115.821
# neighbourhood_Riverdale                  -177.5000    132.147     -1.343      0.179    -436.515      81.515
# neighbourhood_Rockaway Beach              -74.9853     37.934     -1.977      0.048    -149.338      -0.632
# neighbourhood_Roosevelt Island           -137.6689     44.215     -3.114      0.002    -224.333     -51.004
# neighbourhood_Rosebank                   -147.0833    152.508     -0.964      0.335    -446.007     151.840
# neighbourhood_Rosedale                   -180.8958     39.041     -4.633      0.000    -257.419    -104.373
# neighbourhood_Rossville                  -179.7500    186.682     -0.963      0.336    -545.657     186.157
# neighbourhood_Schuylerville              -196.0227     79.988     -2.451      0.014    -352.802     -39.243
# neighbourhood_Sea Gate                     39.5500     83.847      0.472      0.637    -124.794     203.894
# neighbourhood_Sheepshead Bay              -37.2554     28.690     -1.299      0.194     -93.489      18.979
# neighbourhood_Shore Acres                -160.9722     88.335     -1.822      0.068    -334.113      12.169
# neighbourhood_Silver Lake                -158.4167    152.508     -1.039      0.299    -457.340     140.507
# neighbourhood_SoHo                          8.3929     20.442      0.411      0.681     -31.675      48.461
# neighbourhood_Soundview                  -211.9722     88.335     -2.400      0.016    -385.113     -38.831
# neighbourhood_South Beach                -204.7500    152.508     -1.343      0.179    -503.673      94.173
# neighbourhood_South Ozone Park           -166.8611     51.490     -3.241      0.001    -267.784     -65.938
# neighbourhood_South Slope                -107.2056     22.064     -4.859      0.000    -150.452     -63.960
# neighbourhood_Springfield Gardens        -136.6466     29.575     -4.620      0.000    -194.616     -78.677
# neighbourhood_Spuyten Duyvil             -106.0000    132.147     -0.802      0.422    -365.015     153.015
# neighbourhood_St. Albans                 -133.9346     33.842     -3.958      0.000    -200.266     -67.603
# neighbourhood_St. George                 -166.7500     46.053     -3.621      0.000    -257.016     -76.484
# neighbourhood_Stapleton                  -134.4167     68.644     -1.958      0.050    -268.962       0.128
# neighbourhood_Stuyvesant Town            -142.7206     46.053     -3.099      0.002    -232.986     -52.455
# neighbourhood_Sunnyside                  -174.1671     20.122     -8.656      0.000    -213.607    -134.727
# neighbourhood_Sunset Park                -127.3860     19.502     -6.532      0.000    -165.610     -89.162
# neighbourhood_Theater District            -14.1376     21.587     -0.655      0.513     -56.449      28.174
# neighbourhood_Throgs Neck                -165.1029     64.548     -2.558      0.011    -291.620     -38.585
# neighbourhood_Todt Hill                  -203.7500    263.866     -0.772      0.440    -720.941     313.441
# neighbourhood_Tompkinsville              -163.5379     46.721     -3.500      0.000    -255.113     -71.962
# neighbourhood_Tottenville                 126.2500    263.866      0.478      0.632    -390.941     643.441
# neighbourhood_Tremont                    -178.6667     76.623     -2.332      0.020    -328.852     -28.481
# neighbourhood_Tribeca                     135.6063     29.575      4.585      0.000      77.637     193.575
# neighbourhood_Two Bridges                -131.3553     43.652     -3.009      0.003    -216.916     -45.794
# neighbourhood_Unionport                  -125.8929    100.055     -1.258      0.208    -322.006      70.220
# neighbourhood_University Heights         -194.2500     83.847     -2.317      0.021    -358.594     -29.906
# neighbourhood_Upper East Side             -73.7255     12.093     -6.097      0.000     -97.428     -50.023
# neighbourhood_Upper West Side             -60.3543     11.961     -5.046      0.000     -83.798     -36.911
# neighbourhood_Van Nest                   -203.6071    100.055     -2.035      0.042    -399.720      -7.494
# neighbourhood_Vinegar Hill                -87.8500     59.605     -1.474      0.141    -204.679      28.979
# neighbourhood_Wakefield                  -135.2990     37.934     -3.567      0.000    -209.652     -60.946
# neighbourhood_Washington Heights         -159.2843     14.680    -10.851      0.000    -188.057    -130.511
# neighbourhood_West Brighton              -179.4342     61.121     -2.936      0.003    -299.235     -59.634
# neighbourhood_West Farms                 -147.7500    186.682     -0.791      0.429    -513.657     218.157
# neighbourhood_West Village                -10.9988     15.649     -0.703      0.482     -41.672      19.675
# neighbourhood_Westchester Square         -191.7500    152.508     -1.257      0.209    -490.673     107.173
# neighbourhood_Westerleigh                 -94.7500    186.682     -0.508      0.612    -460.657     271.157
# neighbourhood_Whitestone                 -121.8750     93.643     -1.301      0.193    -305.420      61.670
# neighbourhood_Williamsbridge             -170.3952     48.154     -3.539      0.000    -264.780     -76.011
# neighbourhood_Williamsburg               -113.8364     10.469    -10.874      0.000    -134.356     -93.317
# neighbourhood_Willowbrook                  46.2500    263.866      0.175      0.861    -470.941     563.441
# neighbourhood_Windsor Terrace            -139.2206     29.892     -4.658      0.000    -197.810     -80.632
# neighbourhood_Woodhaven                  -180.5700     38.292     -4.716      0.000    -255.624    -105.516
# neighbourhood_Woodlawn                   -138.0000    132.147     -1.044      0.296    -397.015     121.015
# neighbourhood_Woodside                   -193.6190     19.467     -9.946      0.000    -231.776    -155.462
# ==============================================================================
# Omnibus:                    64468.599   Durbin-Watson:                   1.850
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):        695918171.181
# Skew:                          23.188   Prob(JB):                         0.00
# Kurtosis:                     779.147   Cond. No.                         170.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# Exporting image of the above results

plt.rc("figure", figsize=(16 / 1.5, 10 / 1.5), dpi=900)
plt.text(0.01, 0.05, str(est_n.summary()), {"fontsize": 9}, fontproperties="monospace")
plt.axis("off")
plt.tight_layout()
os.makedirs("../artifacts", exist_ok=True)
plt.savefig("../artifacts/reg2.jpeg")
