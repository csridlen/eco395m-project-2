# %%
import pandas as pd

# %%
data_2021 = pd.read_csv("../data/airbnb_listings_2021.csv")
data_2020 = pd.read_csv("../data/AB_US_2020.csv")
data_2019 = pd.read_csv("../data/AB_NYC_2019.csv")
# i think the warning comes from the fact that 2020 has multiple cities so dtypes might be weird. for example a lot of cities will return nulls for neighbourhood or neighboiurhood group
# Out:
# /var/folders/v4/wdkx1z_x4k709_8f6lj5mbm00000gn/T/ipykernel_61454/4274898463.py:2: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_2020 = pd.read_csv("../data/AB_US_2020.csv")

# %%
# Maps of interest:
# number_of_reviews
# price
# room_type
# neighbourhood
# availability_365
# calculated_host_listings_count


# 2020 dataset includes a bunch of areas so filter for new york
data_2020 = data_2020[data_2020["city"] == "New York City"]

# use below to check a host. Some hosts have multiple listings. id and host_id seem to be same properties/people across the 3 datasets.
#data_2021[data_2021["host_id"]==2787]
# Out:
#              id                                               name  host_id  \
# 6074    7937553    Corona free. Riomaggiore Queen Bedroom in Bklyn     2787
# 6363    8426247                 Lg rm in historic bldg by the park     2787
# 8000   10160215                 Corona free.  Torre del Lago Room.     2787
# 8067   10267034   Vernazza Rm. Clean, quiet and available tonight.     2787
# 8068   10267242        Corona free.  Clean and Quiet Queen Bedroom     2787
# 8248   10593675  La Spezia rm.  Clean, quiet and available tonight     2787
# 12075  17263207              Corona free and clean.\nLiguria room.     2787
# 27863  43679750                         Trilevel Brooklyn Townhome     2787
#
#       host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 6074       John            Brooklyn   Bensonhurst  40.60966  -73.97645
# 6363       John            Brooklyn    Kensington  40.64508  -73.97373
# ...
